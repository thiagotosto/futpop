# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /home/ttosto_prest/.local/share/virtualenvs/futpop-fyEu6-Z7/lib/python3.7/site-packages/pandas/compat/__init__.py:84: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# /home/ttosto_prest/.local/share/virtualenvs/futpop-fyEu6-Z7/lib/python3.7/site-packages/pandas/compat/__init__.py:84: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
from pymongo import MongoClient
import configparser

class Mongo():

    def __init__(self, config_file):
        config = configparser.RawConfigParser()
        config.read(config_file)

        self.server = config.get('mongo', 'server') if 'server' in [i[0] for i in config.items('mongo')] else False
        self.db = config.get('mongo', 'db') if 'db' in [i[0] for i in config.items('mongo')] else False
        self.host = config.get('mongo', 'host') if 'host' in [i[0] for i in config.items('mongo')] else False
        self.port = int(config.get('mongo', 'port')) if 'port' in [i[0] for i in config.items('mongo')] else False
        self.user = config.get('mongo', 'user') if 'user' in [i[0] for i in config.items('mongo')] else False
        self.password = config.get('mongo', 'password') if 'password' in [i[0] for i in config.items('mongo')] else False

        print(self.server)
        
    def connect(self):
        if self.server == 'True':
            connection_string_basic = "mongodb+srv://{user}:{password}@{host}{port}{db}".format(user=self.user,
                                                                                                   password=self.password,
                                                                                                   host=self.host,
                                                                                                   port="{port}",
                                                                                                   db="{db}")
        else:
            connection_string_basic = "mongodb://{user}:{password}@{host}{port}{db}".format(user=self.user,
                                                                                            password=self.password,
                                                                                            host=self.host,
                                                                                            port="{port}",
                                                                                            db="{db}")

        if self.port:
            connection_string_port = connection_string_basic.format(port=":{}".format(self.port),
                                                                    db="{db}")
        else:
            connection_string_port = connection_string_basic.format(port="",
                                                                    db="{db}")

        if self.db:
            connection_string = connection_string_port.format(db="/{}".format(self.db))
        else:
            connection_string = connection_string_port.format(db="")
        
        print(connection_string)
        return MongoClient(connection_string)

# %%
mongo = Mongo('config.cfg')
mongo_client = mongo.connect()
# Out:
# True
# mongodb+srv://datapop-user:datapop2710!@cluster0-czab6.mongodb.net/test?retryWrites=true&w=majority

# %%
mongo_client.datapop.tweets_to_classify.aggregate([{"$sample":{"size": 3}}])

# %%
sample = {str(obj['_id']): {i:obj[i] for i in obj if i != '_id'} for obj in mongo_client.datapop.tweets_to_classify.aggregate([{'$sample': {'size': 3}}])}
tweets = {str(obj['_id']): {i:obj[i] for i in obj if i != '_id'} for obj in mongo_client.datapop.tweets_classified.find()}

# %%
tweets_list = [tweets[key] for key in tweets.keys()]

# %%
df_tweets = pd.DataFrame.from_dict(tweets_list)

# %%
df_tweets
# Out:
#                          created_at                   id               id_str  \
# 0    Wed Sep 18 15:17:55 +0000 2019  1174341790633250816  1174341790633250816
# 1    Wed Sep 18 17:05:52 +0000 2019  1174368954254602240  1174368954254602240
# 2    Wed Sep 18 05:17:11 +0000 2019  1174190611257352199  1174190611257352199
# 3    Wed Sep 18 17:04:58 +0000 2019  1174368728252866566  1174368728252866566
# 4    Wed Sep 18 12:55:35 +0000 2019  1174305968202616833  1174305968202616833
# ..                              ...                  ...                  ...
# 272  Mon Sep 23 13:20:23 +0000 2019  1176124151490330624  1176124151490330624
# 273  Mon Sep 23 11:18:59 +0000 2019  1176093600146501633  1176093600146501633
# 274  Thu Sep 19 20:00:48 +0000 2019  1174775366348693504  1174775366348693504
# 275  Sat Sep 21 15:50:08 +0000 2019  1175437062801166338  1175437062801166338
# 276  Sat Sep 21 15:10:55 +0000 2019  1175427192966340609  1175427192966340609
#
#                                              full_text  truncated  \
# 0    @PopeyeNegro @paolo_crf @gabigol @ribasdiego10...      False
# 1    @bezarrade @paolo_crf @gabigol @ribasdiego10 @...      False
# 2            @SouDaNacao Meu Deus @Brunohenrique kkkkk      False
# 3    Veio tomar sopa de garfo,deu nisso aí @phganso...      False
# 4    O Goleiro Muriel de 32 anos, já participou de ...      False
# ..                                                 ...        ...
# 272                 @Flamengo @GiorgiandeA Meu homem 🥺      False
# 273  @br_dadepressao Cebolinha\nBruno Henrique\nGer...      False
# 274  @XandeGalao @duduscarpatti @ESPNagora @Giorgia...      False
# 275       Esse marcinho do botafogo é muito ruim kkkkk      False
# 276  @Flamengo @Deco_SRN @PaparazzoRN @yuripalopoli...      False
#
#     display_text_range                                           entities  \
# 0           [121, 163]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1           [119, 156]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2             [12, 41]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3              [0, 46]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4             [0, 234]  {'hashtags': [], 'symbols': [], 'user_mentions...
# ..                 ...                                                ...
# 272           [23, 34]  {'symbols': [], 'user_mentions': [{'id': 59591...
# 273           [16, 71]  {'symbols': [], 'user_mentions': [{'id': 29691...
# 274           [51, 82]  {'symbols': [], 'user_mentions': [{'id': 26428...
# 275            [0, 44]  {'user_mentions': [], 'symbols': [], 'hashtags...
# 276           [0, 280]  {'user_mentions': [{'indices': [0, 9], 'id': 5...
#
#                                               metadata  \
# 0    {'iso_language_code': 'pt', 'result_type': 're...
# 1    {'iso_language_code': 'pt', 'result_type': 're...
# 2    {'iso_language_code': 'pt', 'result_type': 're...
# 3    {'iso_language_code': 'pt', 'result_type': 're...
# 4    {'iso_language_code': 'pt', 'result_type': 're...
# ..                                                 ...
# 272  {'iso_language_code': 'pt', 'result_type': 're...
# 273  {'iso_language_code': 'pt', 'result_type': 're...
# 274  {'iso_language_code': 'pt', 'result_type': 're...
# 275  {'iso_language_code': 'pt', 'result_type': 're...
# 276  {'iso_language_code': 'pt', 'result_type': 're...
#
#                                                 source  in_reply_to_status_id  \
# 0    <a href="http://twitter.com/download/android" ...           1.174340e+18
# 1    <a href="http://twitter.com/download/android" ...           1.174312e+18
# 2    <a href="http://twitter.com/download/android" ...           1.173958e+18
# 3    <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 4    <a href="http://twitter.com/download/android" ...                    NaN
# ..                                                 ...                    ...
# 272  <a href="http://twitter.com/download/android" ...           1.175875e+18
# 273  <a href="http://twitter.com/download/android" ...           1.175931e+18
# 274  <a href="http://twitter.com/download/iphone" r...           1.174769e+18
# 275  <a href="http://twitter.com/download/iphone" r...                    NaN
# 276  <a href="http://twitter.com/download/android" ...                    NaN
#
#      ... retweeted  lang classified_by rate sentiment quoted_status_id  \
# 0    ...     False    pt  Thiago Tosto    1  negative              NaN
# 1    ...     False    pt  Thiago Tosto    5  positive              NaN
# 2    ...     False    pt  Thiago Tosto    4  positive              NaN
# 3    ...     False    pt  Thiago Tosto    2  negative     1.174352e+18
# 4    ...     False    pt  Thiago Tosto    3   neutral              NaN
# ..   ...       ...   ...           ...  ...       ...              ...
# 272  ...     False    pt  Thiago Tosto    4  positive              NaN
# 273  ...     False    pt  Thiago Tosto    3   neutral              NaN
# 274  ...     False    pt  Thiago Tosto    2  negative              NaN
# 275  ...     False    pt  Thiago Tosto    1  negative              NaN
# 276  ...     False    pt  Thiago Tosto    4  positive              NaN
#
#     quoted_status_id_str                                      quoted_status  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3    1174352379107586049  {'created_at': 'Wed Sep 18 16:00:00 +0000 2019...
# 4                    NaN                                                NaN
# ..                   ...                                                ...
# 272                  NaN                                                NaN
# 273                  NaN                                                NaN
# 274                  NaN                                                NaN
# 275                  NaN                                                NaN
# 276                  NaN                                                NaN
#
#     possibly_sensitive                                  extended_entities
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                False                                                NaN
# 4                False  {'media': [{'id': 1174305959944044544, 'id_str...
# ..                 ...                                                ...
# 272                NaN                                                NaN
# 273                NaN                                                NaN
# 274                NaN                                                NaN
# 275                NaN                                                NaN
# 276                NaN                                                NaN
#
# [277 rows x 33 columns]

# %%
df_tweets.sentiment.value_counts().plot.bar()

# %%
df_positives = df_tweets[df_tweets['sentiment'] == 'positive'][['full_text', 'sentiment', 'rate', 'classified_by']]

# %%
df_neutrals = df_tweets[df_tweets['sentiment'] == 'neutral'][['full_text', 'sentiment', 'rate', 'classified_by']]

# %%
df_negatives = df_tweets[df_tweets['sentiment'] == 'negative'][['full_text', 'sentiment', 'rate', 'classified_by']]

# %%
df_positives
# Out:
#                                              full_text sentiment rate  \
# 1    @bezarrade @paolo_crf @gabigol @ribasdiego10 @...  positive    5
# 2            @SouDaNacao Meu Deus @Brunohenrique kkkkk  positive    4
# 5    @InterAqui @Gui_CRF81 @SCInternacional @Copado...  positive    5
# 7    Tá difícil de parar os coringa do Flamengo, @B...  positive    5
# 8    @Gui_CRF81 @SCInternacional @CopadoBrasil @gab...  positive    5
# ..                                                 ...       ...  ...
# 266  @phganso  esse é o meu 10 KKKKKK https://t.co/...  positive    5
# 269  @Footstats E o @Brunohenrique  ele não pode fi...  positive    5
# 271  @concaoficial @tsilva3 @fredgol9 saudades dema...  positive    5
# 272                 @Flamengo @GiorgiandeA Meu homem 🥺  positive    4
# 276  @Flamengo @Deco_SRN @PaparazzoRN @yuripalopoli...  positive    4
#
#     classified_by
# 1    Thiago Tosto
# 2    Thiago Tosto
# 5    Thiago Tosto
# 7    Thiago Tosto
# 8    Thiago Tosto
# ..            ...
# 266  Thiago Tosto
# 269  Thiago Tosto
# 271  Thiago Tosto
# 272  Thiago Tosto
# 276  Thiago Tosto
#
# [87 rows x 4 columns]

# %%
df_neutrals
# Out:
#                                              full_text sentiment rate  \
# 4    O Goleiro Muriel de 32 anos, já participou de ...   neutral    3
# 6    @InterAqui @SCInternacional @CopadoBrasil @gab...   neutral    3
# 10   @universoffc @FluminenseFC @FluminenseFC @phganso   neutral    3
# 21   @universoffc @FluminenseFC @FluminenseFC @Igor...   neutral    3
# 24   @FluminenseFC @phganso @Nene10 https://t.co/yD...   neutral    3
# ..                                                 ...       ...  ...
# 256  Artilheiros: @gabigol (FLA) 17 gols, Gilberto ...   neutral    3
# 260  Un detallito de esos de Ganso (@phganso ) #Sev...   neutral    3
# 261  Fluminense: Diego Cavalieri , Bruno , Gum , Le...   neutral    3
# 265  @DanielA09566441 @duduscarpatti @ESPNagora @Gi...   neutral    3
# 273  @br_dadepressao Cebolinha\nBruno Henrique\nGer...   neutral    3
#
#     classified_by
# 4    Thiago Tosto
# 6    Thiago Tosto
# 10   Thiago Tosto
# 21   Thiago Tosto
# 24   Thiago Tosto
# ..            ...
# 256  Thiago Tosto
# 260  Thiago Tosto
# 261  Thiago Tosto
# 265  Thiago Tosto
# 273  Thiago Tosto
#
# [93 rows x 4 columns]

# %%
df_negatives
# Out:
#                                              full_text sentiment rate  \
# 0    @PopeyeNegro @paolo_crf @gabigol @ribasdiego10...  negative    1
# 3    Veio tomar sopa de garfo,deu nisso aí @phganso...  negative    2
# 11   @Botafogo Tem q jogar na lateral. Manter Marci...  negative    2
# 18   Melhor dizendo, o adversário chego MUITO MAIS ...  negative    2
# 19   @Botafogo Ver se já renova o contrato cm o Mar...  negative    1
# ..                                                 ...       ...  ...
# 267  @Botafogo Enfia o Pimpao, Marcinho, Fernando, ...  negative    1
# 268  @ArnaldoJRibeiro Arnaldo, FLUMINENSE E CRUZEIR...  negative    1
# 270                    @thneves10 fica tiste não maria  negative    2
# 274  @XandeGalao @duduscarpatti @ESPNagora @Giorgia...  negative    2
# 275       Esse marcinho do botafogo é muito ruim kkkkk  negative    1
#
#     classified_by
# 0    Thiago Tosto
# 3    Thiago Tosto
# 11   Thiago Tosto
# 18   Thiago Tosto
# 19   Thiago Tosto
# ..            ...
# 267  Thiago Tosto
# 268  Thiago Tosto
# 270  Thiago Tosto
# 274  Thiago Tosto
# 275  Thiago Tosto
#
# [97 rows x 4 columns]

# %%
df_tweets.rate.value_counts().sort_index().plot.bar()

# %%
from nltk.corpus import stopwords
import nltk
import re

# %% [markdown]
# ## Tokenizando os textos

# %%
from nltk.tokenize import TweetTokenizer

tweet_tokenizer = TweetTokenizer()

# %%
def collectTokens(tweets):
    list_of_word = []
    for tweet, sentiment in tweets:
        list_of_word = list_of_word + [(token, sentiment) for token in tweet_tokenizer.tokenize(tweet)]
    
    return [token.lower() for token in list_of_word]

# %%
for i in df_tweets[['full_text', 'sentiment']].index:
    print(df_tweets[['full_text', 'sentiment']].iloc[i]['full_text'])
# Out:
# @PopeyeNegro @paolo_crf @gabigol @ribasdiego10 @diegoalvesgol @RCaio03 @evertonri @R13_official @Flamengo @Brunohenrique Podia ter ficado calado! Não sabe de nada!
# @bezarrade @paolo_crf @gabigol @ribasdiego10 @diegoalvesgol @RCaio03 @evertonri @R13_official @Flamengo @Brunohenrique Ajudem nossa pé quente, por favor ❤️🖤
# @SouDaNacao Meu Deus @Brunohenrique kkkkk
# Veio tomar sopa de garfo,deu nisso aí @phganso https://t.co/95gH5tcUk1
# O Goleiro Muriel de 32 anos, já participou de 12 jogos pelo Fluminense e não tomou gol em três.
#
# Corinthians 0 x 0 Fluminense
# Fortaleza 0 x 1 Fluminense
# Fluminense 1 x 0 Fortaleza
#
# Fluminense Notícias é Aqui⤵⤵⤵
# https://t.co/qYM7buhl9m https://t.co/jq2hiqyBx9
# @InterAqui @Gui_CRF81 @SCInternacional @CopadoBrasil @gabigol @Brunohenrique @GiorgiandeA
# @LimaRodrigoS @duduscarpatti @ESPNagora @GiorgiandeA PSER MERMAO, torcedor pode empolgar sim desde que seja com respeito.
# Un detallito de esos de Ganso (@phganso ) #SevillaFC https://t.co/6pJ5XSo16N
# Fluminense: Diego Cavalieri , Bruno , Gum , Leandro Euzébio (Digão) e Thiago Carleto; Valencia , Jean , @Deco20oficial (Wagner) e @thneves10 (@marcosjr35); Wellington Nem e @fredgol9. Técnico: Abel Braga
# @Andre_Dolinski @guerrilheirocap @CopadoBrasil @brunoog97 Muito loco 👏👏🌪
# @alberto_medrado @MatheusOma @luizz_gustavo13 @centraldanacao Quero ver vc repetir isso apos o Everton Cebolinha destruir ele
# Tem como rescindir o contrato do @phganso ???? 5 anos aturando um jogador morto é sacanagem.
# @DanielA09566441 @duduscarpatti @ESPNagora @GiorgiandeA Isso aí eles já têm... e boa parte da torcida também.
# @phganso  esse é o meu 10 KKKKKK https://t.co/xBTbOBJK1H
# @Botafogo Enfia o Pimpao, Marcinho, Fernando, Rangel no cú seus fdp..
# @ArnaldoJRibeiro Arnaldo, FLUMINENSE E CRUZEIRO sem dois dos principais nomes do time... É inaceitável perder jogador em jogo de fundamental importância pra temporada em jogo de sub-23
# @Footstats E o @Brunohenrique  ele não pode ficar de fora o cara joga muito
# @thneves10 fica tiste não maria
# @concaoficial @tsilva3 @fredgol9 saudades demais....
# @Flamengo @GiorgiandeA Meu homem 🥺
# @br_dadepressao Cebolinha
# Bruno Henrique
# Gerson
# Gabigol
# Everton Ribeiro
# @XandeGalao @duduscarpatti @ESPNagora @GiorgiandeA De série b vocês entendem kkkkk
# Esse marcinho do botafogo é muito ruim kkkkk
# @Flamengo @Deco_SRN @PaparazzoRN @yuripalopoli @gabigol @GiorgiandeA @GersonSantos08 sei q é dia de jogo,concentraçâo total e pra cima deles! Amanhã é aniversario da Ana Luiza(afilhada da minha noiva e minha "sobrinha") vou dar o 1 manto personalizado pra ela! Ela é fá do Gabigol

# %%
tokens = collectTokens([(df_tweets[['full_text', 'sentiment']].iloc[i]['full_text'],
                         df_tweets[['full_text', 'sentiment']].iloc[i]['sentiment']) for i in df_tweets[['full_text',
                                                                                                        'sentiment']].index])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-149-3f016af10ec8> in <module>
#       1 tokens = collectTokens([(df_tweets[['full_text', 'sentiment']].iloc[i]['full_text'],
#       2                          df_tweets[['full_text', 'sentiment']].iloc[i]['sentiment']) for i in df_tweets[['full_text',
# ----> 3                                                                                                         'sentiment']].index])
#
# <ipython-input-145-cf4e78cfc2a8> in collectTokens(tweets)
#       4         list_of_word = list_of_word + [(token, sentiment) for token in tweet_tokenizer.tokenize(tweet)]
#       5
# ----> 6     return [token.lower() for token in list_of_word]
#       7
#
# <ipython-input-145-cf4e78cfc2a8> in <listcomp>(.0)
#       4         list_of_word = list_of_word + [(token, sentiment) for token in tweet_tokenizer.tokenize(tweet)]
#       5
# ----> 6     return [token.lower() for token in list_of_word]
#       7
#
# AttributeError: 'tuple' object has no attribute 'lower'

# %%
len(tokens)
# Out:
# 5761

# %%
tokens
# Out:
# ['@popeyenegro',
#  '@paolo_crf',
#  '@gabigol',
#  '@ribasdiego10',
#  '@diegoalvesgol',
#  '@rcaio03',
#  '@evertonri',
#  '@r13_official',
#  '@flamengo',
#  '@brunohenrique',
#  'podia',
#  'ter',
#  'ficado',
#  'calado',
#  '!',
#  'não',
#  'sabe',
#  'de',
#  'nada',
#  '!',
#  '@bezarrade',
#  '@paolo_crf',
#  '@gabigol',
#  '@ribasdiego10',
#  '@diegoalvesgol',
#  '@rcaio03',
#  '@evertonri',
#  '@r13_official',
#  '@flamengo',
#  '@brunohenrique',
#  'ajudem',
#  'nossa',
#  'pé',
#  'quente',
#  ',',
#  'por',
#  'favor',
#  '❤',
#  '️',
#  '🖤',
#  '@soudanacao',
#  'meu',
#  'deus',
#  '@brunohenrique',
#  'kkkkk',
#  'veio',
#  'tomar',
#  'sopa',
#  'de',
#  'garfo',
#  ',',
#  'deu',
#  'nisso',
#  'aí',
#  '@phganso',
#  'https://t.co/95gh5tcuk1',
#  'o',
#  'goleiro',
#  'muriel',
#  'de',
#  '32',
#  'anos',
#  ',',
#  'já',
#  'participou',
#  'de',
#  '12',
#  'jogos',
#  'pelo',
#  'fluminense',
#  'e',
#  'não',
#  'tomou',
#  'gol',
#  'em',
#  'três',
#  '.',
#  'corinthians',
#  '0',
#  'x',
#  '0',
#  'fluminense',
#  'fortaleza',
#  '0',
#  'x',
#  '1',
#  'fluminense',
#  'fluminense',
#  '1',
#  'x',
#  '0',
#  'fortaleza',
#  'fluminense',
#  'notícias',
#  'é',
#  'aqui',
#  '⤵',
#  '⤵',
#  '⤵',
#  'https://t.co/qym7buhl9m',
#  'https://t.co/jq2hiqybx9',
#  '@interaqui',
#  '@gui_crf81',
#  '@scinternacional',
#  '@copadobrasil',
#  '@gabigol',
#  '@brunohenrique',
#  '@giorgiandea',
#  'síndrome',
#  'de',
#  'estocolmo',
#  '🤣',
#  '🤣',
#  '🤣',
#  '@interaqui',
#  '@scinternacional',
#  '@copadobrasil',
#  '@gabigol',
#  '@brunohenrique',
#  '@giorgiandea',
#  'pqp',
#  'kkkkkk',
#  'tá',
#  'difícil',
#  'de',
#  'parar',
#  'os',
#  'coringa',
#  'do',
#  'flamengo',
#  ',',
#  '@brunohenrique',
#  '@giorgiandea',
#  'e',
#  'nosso',
#  'menino',
#  '@gersonsantos08',
#  'se',
#  'tem',
#  'jogo',
#  'do',
#  'mengão',
#  'a',
#  'torcida',
#  'da',
#  'um',
#  'show',
#  'pode',
#  'levantar',
#  'a',
#  'plaquinha',
#  'hj',
#  'tem',
#  'gol',
#  'do',
#  '@gabigol',
#  '🔴',
#  '⚫',
#  '🔴',
#  '⚫',
#  '🔴',
#  '⚫',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '@gui_crf81',
#  '@scinternacional',
#  '@copadobrasil',
#  '@gabigol',
#  '@brunohenrique',
#  '@giorgiandea',
#  'dá',
#  'de',
#  'chapa',
#  'na',
#  'vola',
#  'kkkkkkkkkkkk',
#  'abraço',
#  'cara',
#  'durma',
#  'bem',
#  '@phganso',
#  '@universoffc',
#  '@fluminensefc',
#  '@fluminensefc',
#  '@phganso',
#  '@botafogo',
#  'tem',
#  'q',
#  'jogar',
#  'na',
#  'lateral',
#  '.',
#  'manter',
#  'marcinho',
#  'na',
#  'meia',
#  'e',
#  'mandar',
#  'fernando',
#  'de',
#  'volta',
#  'pra',
#  'frança',
#  '.',
#  '@flamengo',
#  '@gabigol',
#  '@brunohenrique',
#  'vão',
#  'trazer',
#  'a',
#  'liberta',
#  '@interaqui',
#  '@scinternacional',
#  '@copadobrasil',
#  '@gabigol',
#  '@brunohenrique',
#  '@giorgiandea',
#  'deixa',
#  'com',
#  'a',
#  'gente',
#  ',',
#  'é',
#  'so',
#  'vapo',
#  'vapo',
#  '🙅',
#  '🏻',
#  '\u200d',
#  '♂',
#  '️',
#  'meu',
#  'sonho',
#  'é',
#  'ir',
#  'no',
#  'maraca',
#  'com',
#  'os',
#  'amigos',
#  'e',
#  'celebrar',
#  'vendo',
#  'o',
#  'flamengo',
#  'joga',
#  '!',
#  '!',
#  '!',
#  'nunca',
#  'fui',
#  'no',
#  'maracanã',
#  'e',
#  'gostaria',
#  'muito',
#  'de',
#  'realizar',
#  'esse',
#  'sonho',
#  '!',
#  'não',
#  'quero',
#  'nada',
#  '!',
#  'só',
#  'quero',
#  'ver',
#  'o',
#  'flamengo',
#  'joga',
#  'e',
#  'sentir',
#  'a',
#  'emoção',
#  'do',
#  'maraca',
#  '!',
#  '@flamengo',
#  '@flaesports',
#  '@timeflamengo',
#  '@brunohenrique',
#  '@gui_crf81',
#  '@scinternacional',
#  '@copadobrasil',
#  '@gabigol',
#  '@brunohenrique',
#  '@giorgiandea',
#  'ah',
#  'ta',
#  'kkk',
#  'achei',
#  'que',
#  'tu',
#  'tava',
#  'dando',
#  'uma',
#  'zicada',
#  'sei',
#  'la',
#  'kkkkkkkkk',
#  'ja',
#  'que',
#  'passeram',
#  'aqui',
#  'em',
#  'poa',
#  '.',
#  'enfim',
#  ',',
#  'elimina',
#  'o',
#  'gremio',
#  'ai',
#  'que',
#  'ta',
#  'tudo',
#  'certo',
#  'kkkkkkkkk',
#  '@marcellustheroc',
#  '@paolo_crf',
#  '@gabigol',
#  '@ribasdiego10',
#  '@diegoalvesgol',
#  '@rcaio03',
#  '@evertonri',
#  '@r13_official',
#  '@flamengo',
#  '@brunohenrique',
#  'qual',
#  'é',
#  'a',
#  'definição',
#  'de',
#  'pé',
#  'quente',
#  'pra',
#  'vc',
#  '?',
#  'dou',
#  'sorte',
#  'mesmo',
#  ',',
#  'o',
#  'que',
#  'eu',
#  'posso',
#  'fazer',
#  'se',
#  'não',
#  'vi',
#  'meu',
#  'time',
#  'perder',
#  'nos',
#  'trocentos',
#  'jogos',
#  'que',
#  'fui',
#  '?',
#  'muitas',
#  'pessoas',
#  'já',
#  'foram',
#  'aos',
#  'jogos',
#  'e',
#  'viram',
#  'perder',
#  ',',
#  'eu',
#  '🙏',
#  'não',
#  'vi',
#  '!',
#  'muito',
#  'triste',
#  '!',
#  '!',
#  'desde',
#  '1981',
#  'nunca',
#  'vi',
#  'meu',
#  'time',
#  'perder',
#  'no',
#  'maraca',
#  '!',
#  'sou',
#  'sts',
#  'e',
#  'não',
#  'consegui',
#  'ingresso',
#  'pro',
#  'dia',
#  '23/10',
#  ',',
#  'sou',
#  'pé',
#  'quente',
#  'e',
#  'não',
#  'vou',
#  'poder',
#  'ir',
#  '!',
#  'será',
#  'que',
#  'vcs',
#  'não',
#  'podem',
#  'me',
#  'ajudar',
#  '?',
#  '@gabigol',
#  '@ribasdiego10',
#  '@diegoalvesgol',
#  '@rcaio03',
#  '@evertonri',
#  '@r13_official',
#  '@flamengo',
#  '@brunohenrique',
#  'melhor',
#  'dizendo',
#  ',',
#  'o',
#  'adversário',
#  'chego',
#  'muito',
#  'mais',
#  'ao',
#  'gol',
#  'do',
#  'fluminense',
#  ',',
#  'muriel',
#  'tá',
#  'se',
#  'destacando',
#  ',',
#  'odeio',
#  'esse',
#  'treinador',
#  'medroso',
#  'medíocre',
#  'https://t.co/ajap6gfd3d',
#  '@botafogo',
#  'ver',
#  'se',
#  'já',
#  'renova',
#  'o',
#  'contrato',
#  'cm',
#  'o',
#  'marcinho',
#  'seus',
#  'amadores',
#  ',',
#  'do',
#  'jeito',
#  'q',
#  'são',
#  'vão',
#  'deixar',
#  'sair',
#  'de',
#  'graça',
#  '.',
#  '@interaqui',
#  '@scinternacional',
#  '@copadobrasil',
#  '@gabigol',
#  '@brunohenrique',
#  '@giorgiandea',
#  'ele',
#  'q',
#  'jogou',
#  'baixo',
#  'na',
#  'liberta',
#  'postando',
#  'merda',
#  ',',
#  'não',
#  'eu',
#  'kkkkk',
#  '@universoffc',
#  '@fluminensefc',
#  '@fluminensefc',
#  '@igorjuliao2',
#  '@pedrogilio',
#  '@phganso',
#  'fluminense',
#  'precisa',
#  'se',
#  'livrar',
#  'de',
#  'kelvin',
#  ',',
#  'ewandro',
#  ',',
#  'agenor',
#  ',',
#  'guilherme',
#  ',',
#  'brenner',
#  ',',
#  'digão',
#  ',',
#  'gilberto',
#  ',',
#  'daniel',
#  ',',
#  'airton',
#  ',',
#  'caio',
#  ',',
#  'pablo',
#  'dyego',
#  'e',
#  'dodi',
#  'pra',
#  '2020',
#  'urgente',
#  '.',
#  'pelo',
#  'menos',
#  'uns',
#  '500',
#  'mil',
#  'que',
#  'já',
#  'pagaria',
#  'um',
#  'jogador',
#  '100x',
#  'melhor',
#  'que',
#  'todos',
#  'juntos',
#  'bom',
#  'dia',
#  '❤',
#  '️',
#  '🖤',
#  'segue',
#  'o',
#  'líder',
#  '@gabigol',
#  '@r13_official',
#  '@evertonri',
#  '@brunohenrique',
#  '@giorgiandea',
#  'https://t.co/voqjpqhl53',
#  '@fluminensefc',
#  '@phganso',
#  '@nene10',
#  'https://t.co/ydtk8hugjv',
#  'que',
#  'timaço',
#  'da',
#  'po',
#  '%',
#  '#',
#  '#wednesdaywisdom',
#  '#flamengo',
#  '#flatv',
#  '@flamengo',
#  '@diegoalvesgol',
#  '@r13_official',
#  '@rcaio03',
#  '@pablomv5',
#  '@willianarao',
#  '@gersonsantos08',
#  '@evertonri',
#  '@giorgiandea',
#  '@brunohenrique',
#  'e',
#  '@gabigol',
#  '@adriano7machado',
#  'https://t.co/sztcegzji0',
#  '@felipaobfr',
#  'mas',
#  'eu',
#  'acredito',
#  'na',
#  'vitória',
#  '!',
#  'time',
#  'do',
#  '@botafogo',
#  'não',
#  'precisa',
#  'mudar',
#  'de',
#  'atitude',
#  ',',
#  'a',
#  'gente',
#  'ainda',
#  'tenta',
#  'ficar',
#  'com',
#  'a',
#  'bola',
#  'estudo',
#  'mais',
#  '.',
#  'acho',
#  'q',
#  'tem',
#  'q',
#  'mudar',
#  'algumas',
#  'peças',
#  'por',
#  'mais',
#  'q',
#  'olhar',
#  'p',
#  '/',
#  'o',
#  'banco',
#  'dê',
#  'medo',
#  '!',
#  'l.fernando',
#  'é',
#  'dose',
#  ',',
#  'ds7',
#  'dá',
#  'tirando',
#  'a',
#  'paciência',
#  ',',
#  'e',
#  'tão',
#  'cavando',
#  'qq',
#  'vaga',
#  'p',
#  '/',
#  'marcinho',
#  '!',
#  '@tg_mck',
#  '@flamengo',
#  '@giorgiandea',
#  'bora',
#  'pra',
#  'praia',
#  'amanhã',
#  ',',
#  'peida',
#  '?',
#  '@universoffc',
#  '@fluminensefc',
#  '@pedrogilio',
#  '@dejesusofiicial',
#  '@nene10',
#  '@andrizek',
#  'engraçado',
#  '@andrizek',
#  'pq',
#  'isso',
#  'só',
#  'agora',
#  '?',
#  '?',
#  'pq',
#  'isso',
#  'só',
#  'este',
#  'a',
#  'ano',
#  '?',
#  'por',
#  'ex',
#  ':',
#  'quando',
#  'o',
#  '@santosfc',
#  'tinha',
#  '2',
#  ',',
#  '3',
#  'jogadores',
#  '@neymarjr',
#  '@phganso',
#  '@robinho',
#  'convocados',
#  'para',
#  '#cbflixo',
#  'não',
#  'li',
#  'nenhuma',
#  'nota',
#  'neste',
#  'sentido',
#  '..',
#  'agora',
#  'pq',
#  'o',
#  'cheirinho',
#  'esta',
#  'lá',
#  'vc',
#  'solta',
#  'dessa',
#  '!',
#  '!',
#  '@xamaoficial',
#  '@mumuzinhoc',
#  '@a10imperador',
#  '@diegoalvesgol',
#  '@gabigol',
#  '@lucaspaqueta97',
#  '@josealdojunior',
#  '@datenaoficial',
#  '@brunohenrique',
#  '@balancogeral',
#  '@recordtv_press',
#  '@gui_crf81',
#  '@scinternacional',
#  '@copadobrasil',
#  '@gabigol',
#  '@brunohenrique',
#  '@giorgiandea',
#  'nao',
#  'me',
#  'ofende',
#  'cara',
#  ',',
#  'agora',
#  'tu',
#  'jogou',
#  'baixo',
#  'kkkkkkkk',
#  '@marcellocravo',
#  '@paolo_crf',
#  '@gabigol',
#  '@ribasdiego10',
#  '@diegoalvesgol',
#  '@rcaio03',
#  '@evertonri',
#  '@r13_official',
#  '@flamengo',
#  '@brunohenrique',
#  'nem',
#  'todos',
#  'os',
#  'meses',
#  'eu',
#  'consigo',
#  'ir',
#  ',',
#  'ainda',
#  'mais',
#  'que',
#  'não',
#  'moro',
#  'mais',
#  'no',
#  'rio',
#  ',',
#  'mas',
#  'já',
#  'fui',
#  'a',
#  'muitooooos',
#  'jogos',
#  ',',
#  'não',
#  'preciso',
#  'mentir',
#  ',',
#  'não',
#  'vi',
#  'o',
#  'flamengo',
#  'perder',
#  'mesmo',
#  '.',
#  '#redacaosportv',
#  'a',
#  'música',
#  'do',
#  'gilberto',
#  'gil',
#  'não',
#  'é',
#  'uma',
#  'homenagem',
#  'ao',
#  'flamengo',
#  ',',
#  'pelo',
#  'contrário',
#  ',',
#  'tricolor',
#  'como',
#  'é',
#  ',',
#  'gil',
#  'fez',
#  'uma',
#  'provocação',
#  'com',
#  'os',
#  'flamenguistas',
#  'pois',
#  'o',
#  'fluminense',
#  'tinha',
#  'acabado',
#  'de',
#  'ser',
#  'campeão',
#  '!',
#  '!',
#  '!',
#  '@universoffc',
#  '@fluminensefc',
#  '@fluminensefc',
#  '@dejesusofiicial',
#  '@igorjuliao2',
#  '@nene10',
#  '@oflumedomina',
#  '@brunohenrique',
#  '@universoffc',
#  '@fluminensefc',
#  '@fluminensefc',
#  '@nene10',
#  '@flamengo',
#  '@giorgiandea',
#  'eu',
#  'amo',
#  'uma',
#  'seleção',
#  '❤',
#  '️',
#  '@bezarrade',
#  '@paolo_crf',
#  '@gabigol',
#  '@ribasdiego10',
#  '@diegoalvesgol',
#  '@rcaio03',
#  '@evertonri',
#  '@r13_official',
#  '@flamengo',
#  '@brunohenrique',
#  '@yuripalopoli',
#  '@mlktete',
#  '@brunohenrique',
#  'kkkkkkk',
#  'o',
#  'goleiro',
#  'do',
#  'fluminense',
#  'não',
#  'se',
#  'chama',
#  'muriel',
#  '?',
#  'https://t.co/grc6cd8eew',
#  '@fluminensefc',
#  '@nene10',
#  '=',
#  'tudo',
#  'pra',
#  'mim',
#  '.',
#  '@victormatheusb7',
#  'o',
#  'var',
#  'quase',
#  'sempre',
#  'funciona',
#  'contra',
#  'o',
#  'fluminense',
#  'rs',
#  'o',
#  'sistema',
#  'é',
#  'foda',
#  '-',
#  '@phganso',
#  '@fredcruzeiro19',
#  '@ricarvalho_pc',
#  '@giorgiandea',
#  'não',
#  'existe',
#  'opinião',
#  'quanto',
#  'a',
#  'tratamento',
#  'de',
#  'rival',
#  '.',
#  'você',
#  'não',
#  'entendeu',
#  'até',
#  'agora',
#  'que',
#  'é',
#  'um',
#  'ex-funcionário',
#  'do',
#  'clube',
#  ',',
#  'e',
#  'agora',
#  'é',
#  'de',
#  'um',
#  'clube',
#  'rival',
#  'ou',
#  'tem',
#  'que',
#  'desenhar',
#  '?',
#  'agradecimentos',
#  'foram',
#  'dados',
#  'e',
#  'agora',
#  'é',
#  'contra',
#  'o',
#  'cruzeiro',
#  '.',
#  '@territoriorn',
#  '@marcellocravo',
#  '@paolo_crf',
#  '@gabigol',
#  '@ribasdiego10',
#  '@diegoalvesgol',
#  '@rcaio03',
#  '@evertonri',
#  '@r13_official',
#  '@flamengo',
#  '@brunohenrique',
#  'não',
#  'entendi',
#  'sua',
#  'resposta',
#  '?',
#  'vc',
#  'estava',
#  'na',
#  'virada',
#  ...]

# %% [markdown]
# ## Removendo Stopwords

# %%
portuguese_stop_words = stopwords.words('portuguese')

# %%
def removeStopwords(tokens):
    return [token for token in tokens if token not in portuguese_stop_words]

# %%
tokens_no_stopwords = removeStopwords(tokens)

# %%
len(tokens_no_stopwords)
# Out:
# 4358

# %%
tokens_no_stopwords
# Out:
# ['@popeyenegro',
#  '@paolo_crf',
#  '@gabigol',
#  '@ribasdiego10',
#  '@diegoalvesgol',
#  '@rcaio03',
#  '@evertonri',
#  '@r13_official',
#  '@flamengo',
#  '@brunohenrique',
#  'podia',
#  'ter',
#  'ficado',
#  'calado',
#  '!',
#  'sabe',
#  'nada',
#  '!',
#  '@bezarrade',
#  '@paolo_crf',
#  '@gabigol',
#  '@ribasdiego10',
#  '@diegoalvesgol',
#  '@rcaio03',
#  '@evertonri',
#  '@r13_official',
#  '@flamengo',
#  '@brunohenrique',
#  'ajudem',
#  'pé',
#  'quente',
#  ',',
#  'favor',
#  '❤',
#  '️',
#  '🖤',
#  '@soudanacao',
#  'deus',
#  '@brunohenrique',
#  'kkkkk',
#  'veio',
#  'tomar',
#  'sopa',
#  'garfo',
#  ',',
#  'deu',
#  'nisso',
#  'aí',
#  '@phganso',
#  'https://t.co/95gh5tcuk1',
#  'goleiro',
#  'muriel',
#  '32',
#  'anos',
#  ',',
#  'participou',
#  '12',
#  'jogos',
#  'fluminense',
#  'tomou',
#  'gol',
#  'três',
#  '.',
#  'corinthians',
#  '0',
#  'x',
#  '0',
#  'fluminense',
#  'fortaleza',
#  '0',
#  'x',
#  '1',
#  'fluminense',
#  'fluminense',
#  '1',
#  'x',
#  '0',
#  'fortaleza',
#  'fluminense',
#  'notícias',
#  'aqui',
#  '⤵',
#  '⤵',
#  '⤵',
#  'https://t.co/qym7buhl9m',
#  'https://t.co/jq2hiqybx9',
#  '@interaqui',
#  '@gui_crf81',
#  '@scinternacional',
#  '@copadobrasil',
#  '@gabigol',
#  '@brunohenrique',
#  '@giorgiandea',
#  'síndrome',
#  'estocolmo',
#  '🤣',
#  '🤣',
#  '🤣',
#  '@interaqui',
#  '@scinternacional',
#  '@copadobrasil',
#  '@gabigol',
#  '@brunohenrique',
#  '@giorgiandea',
#  'pqp',
#  'kkkkkk',
#  'tá',
#  'difícil',
#  'parar',
#  'coringa',
#  'flamengo',
#  ',',
#  '@brunohenrique',
#  '@giorgiandea',
#  'menino',
#  '@gersonsantos08',
#  'jogo',
#  'mengão',
#  'torcida',
#  'show',
#  'pode',
#  'levantar',
#  'plaquinha',
#  'hj',
#  'gol',
#  '@gabigol',
#  '🔴',
#  '⚫',
#  '🔴',
#  '⚫',
#  '🔴',
#  '⚫',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '@gui_crf81',
#  '@scinternacional',
#  '@copadobrasil',
#  '@gabigol',
#  '@brunohenrique',
#  '@giorgiandea',
#  'dá',
#  'chapa',
#  'vola',
#  'kkkkkkkkkkkk',
#  'abraço',
#  'cara',
#  'durma',
#  'bem',
#  '@phganso',
#  '@universoffc',
#  '@fluminensefc',
#  '@fluminensefc',
#  '@phganso',
#  '@botafogo',
#  'q',
#  'jogar',
#  'lateral',
#  '.',
#  'manter',
#  'marcinho',
#  'meia',
#  'mandar',
#  'fernando',
#  'volta',
#  'pra',
#  'frança',
#  '.',
#  '@flamengo',
#  '@gabigol',
#  '@brunohenrique',
#  'vão',
#  'trazer',
#  'liberta',
#  '@interaqui',
#  '@scinternacional',
#  '@copadobrasil',
#  '@gabigol',
#  '@brunohenrique',
#  '@giorgiandea',
#  'deixa',
#  'gente',
#  ',',
#  'so',
#  'vapo',
#  'vapo',
#  '🙅',
#  '🏻',
#  '\u200d',
#  '♂',
#  '️',
#  'sonho',
#  'ir',
#  'maraca',
#  'amigos',
#  'celebrar',
#  'vendo',
#  'flamengo',
#  'joga',
#  '!',
#  '!',
#  '!',
#  'nunca',
#  'maracanã',
#  'gostaria',
#  'realizar',
#  'sonho',
#  '!',
#  'quero',
#  'nada',
#  '!',
#  'quero',
#  'ver',
#  'flamengo',
#  'joga',
#  'sentir',
#  'emoção',
#  'maraca',
#  '!',
#  '@flamengo',
#  '@flaesports',
#  '@timeflamengo',
#  '@brunohenrique',
#  '@gui_crf81',
#  '@scinternacional',
#  '@copadobrasil',
#  '@gabigol',
#  '@brunohenrique',
#  '@giorgiandea',
#  'ah',
#  'ta',
#  'kkk',
#  'achei',
#  'tava',
#  'dando',
#  'zicada',
#  'sei',
#  'la',
#  'kkkkkkkkk',
#  'ja',
#  'passeram',
#  'aqui',
#  'poa',
#  '.',
#  'enfim',
#  ',',
#  'elimina',
#  'gremio',
#  'ai',
#  'ta',
#  'tudo',
#  'certo',
#  'kkkkkkkkk',
#  '@marcellustheroc',
#  '@paolo_crf',
#  '@gabigol',
#  '@ribasdiego10',
#  '@diegoalvesgol',
#  '@rcaio03',
#  '@evertonri',
#  '@r13_official',
#  '@flamengo',
#  '@brunohenrique',
#  'definição',
#  'pé',
#  'quente',
#  'pra',
#  'vc',
#  '?',
#  'dou',
#  'sorte',
#  ',',
#  'posso',
#  'fazer',
#  'vi',
#  'time',
#  'perder',
#  'trocentos',
#  'jogos',
#  '?',
#  'muitas',
#  'pessoas',
#  'jogos',
#  'viram',
#  'perder',
#  ',',
#  '🙏',
#  'vi',
#  '!',
#  'triste',
#  '!',
#  '!',
#  'desde',
#  '1981',
#  'nunca',
#  'vi',
#  'time',
#  'perder',
#  'maraca',
#  '!',
#  'sts',
#  'consegui',
#  'ingresso',
#  'pro',
#  'dia',
#  '23/10',
#  ',',
#  'pé',
#  'quente',
#  'vou',
#  'poder',
#  'ir',
#  '!',
#  'vcs',
#  'podem',
#  'ajudar',
#  '?',
#  '@gabigol',
#  '@ribasdiego10',
#  '@diegoalvesgol',
#  '@rcaio03',
#  '@evertonri',
#  '@r13_official',
#  '@flamengo',
#  '@brunohenrique',
#  'melhor',
#  'dizendo',
#  ',',
#  'adversário',
#  'chego',
#  'gol',
#  'fluminense',
#  ',',
#  'muriel',
#  'tá',
#  'destacando',
#  ',',
#  'odeio',
#  'treinador',
#  'medroso',
#  'medíocre',
#  'https://t.co/ajap6gfd3d',
#  '@botafogo',
#  'ver',
#  'renova',
#  'contrato',
#  'cm',
#  'marcinho',
#  'amadores',
#  ',',
#  'jeito',
#  'q',
#  'vão',
#  'deixar',
#  'sair',
#  'graça',
#  '.',
#  '@interaqui',
#  '@scinternacional',
#  '@copadobrasil',
#  '@gabigol',
#  '@brunohenrique',
#  '@giorgiandea',
#  'q',
#  'jogou',
#  'baixo',
#  'liberta',
#  'postando',
#  'merda',
#  ',',
#  'kkkkk',
#  '@universoffc',
#  '@fluminensefc',
#  '@fluminensefc',
#  '@igorjuliao2',
#  '@pedrogilio',
#  '@phganso',
#  'fluminense',
#  'precisa',
#  'livrar',
#  'kelvin',
#  ',',
#  'ewandro',
#  ',',
#  'agenor',
#  ',',
#  'guilherme',
#  ',',
#  'brenner',
#  ',',
#  'digão',
#  ',',
#  'gilberto',
#  ',',
#  'daniel',
#  ',',
#  'airton',
#  ',',
#  'caio',
#  ',',
#  'pablo',
#  'dyego',
#  'dodi',
#  'pra',
#  '2020',
#  'urgente',
#  '.',
#  'menos',
#  'uns',
#  '500',
#  'mil',
#  'pagaria',
#  'jogador',
#  '100x',
#  'melhor',
#  'todos',
#  'juntos',
#  'bom',
#  'dia',
#  '❤',
#  '️',
#  '🖤',
#  'segue',
#  'líder',
#  '@gabigol',
#  '@r13_official',
#  '@evertonri',
#  '@brunohenrique',
#  '@giorgiandea',
#  'https://t.co/voqjpqhl53',
#  '@fluminensefc',
#  '@phganso',
#  '@nene10',
#  'https://t.co/ydtk8hugjv',
#  'timaço',
#  'po',
#  '%',
#  '#',
#  '#wednesdaywisdom',
#  '#flamengo',
#  '#flatv',
#  '@flamengo',
#  '@diegoalvesgol',
#  '@r13_official',
#  '@rcaio03',
#  '@pablomv5',
#  '@willianarao',
#  '@gersonsantos08',
#  '@evertonri',
#  '@giorgiandea',
#  '@brunohenrique',
#  '@gabigol',
#  '@adriano7machado',
#  'https://t.co/sztcegzji0',
#  '@felipaobfr',
#  'acredito',
#  'vitória',
#  '!',
#  'time',
#  '@botafogo',
#  'precisa',
#  'mudar',
#  'atitude',
#  ',',
#  'gente',
#  'ainda',
#  'tenta',
#  'ficar',
#  'bola',
#  'estudo',
#  '.',
#  'acho',
#  'q',
#  'q',
#  'mudar',
#  'algumas',
#  'peças',
#  'q',
#  'olhar',
#  'p',
#  '/',
#  'banco',
#  'dê',
#  'medo',
#  '!',
#  'l.fernando',
#  'dose',
#  ',',
#  'ds7',
#  'dá',
#  'tirando',
#  'paciência',
#  ',',
#  'tão',
#  'cavando',
#  'qq',
#  'vaga',
#  'p',
#  '/',
#  'marcinho',
#  '!',
#  '@tg_mck',
#  '@flamengo',
#  '@giorgiandea',
#  'bora',
#  'pra',
#  'praia',
#  'amanhã',
#  ',',
#  'peida',
#  '?',
#  '@universoffc',
#  '@fluminensefc',
#  '@pedrogilio',
#  '@dejesusofiicial',
#  '@nene10',
#  '@andrizek',
#  'engraçado',
#  '@andrizek',
#  'pq',
#  'agora',
#  '?',
#  '?',
#  'pq',
#  'ano',
#  '?',
#  'ex',
#  ':',
#  '@santosfc',
#  '2',
#  ',',
#  '3',
#  'jogadores',
#  '@neymarjr',
#  '@phganso',
#  '@robinho',
#  'convocados',
#  '#cbflixo',
#  'li',
#  'nenhuma',
#  'nota',
#  'neste',
#  'sentido',
#  '..',
#  'agora',
#  'pq',
#  'cheirinho',
#  'lá',
#  'vc',
#  'solta',
#  'dessa',
#  '!',
#  '!',
#  '@xamaoficial',
#  '@mumuzinhoc',
#  '@a10imperador',
#  '@diegoalvesgol',
#  '@gabigol',
#  '@lucaspaqueta97',
#  '@josealdojunior',
#  '@datenaoficial',
#  '@brunohenrique',
#  '@balancogeral',
#  '@recordtv_press',
#  '@gui_crf81',
#  '@scinternacional',
#  '@copadobrasil',
#  '@gabigol',
#  '@brunohenrique',
#  '@giorgiandea',
#  'nao',
#  'ofende',
#  'cara',
#  ',',
#  'agora',
#  'jogou',
#  'baixo',
#  'kkkkkkkk',
#  '@marcellocravo',
#  '@paolo_crf',
#  '@gabigol',
#  '@ribasdiego10',
#  '@diegoalvesgol',
#  '@rcaio03',
#  '@evertonri',
#  '@r13_official',
#  '@flamengo',
#  '@brunohenrique',
#  'todos',
#  'meses',
#  'consigo',
#  'ir',
#  ',',
#  'ainda',
#  'moro',
#  'rio',
#  ',',
#  'muitooooos',
#  'jogos',
#  ',',
#  'preciso',
#  'mentir',
#  ',',
#  'vi',
#  'flamengo',
#  'perder',
#  '.',
#  '#redacaosportv',
#  'música',
#  'gilberto',
#  'gil',
#  'homenagem',
#  'flamengo',
#  ',',
#  'contrário',
#  ',',
#  'tricolor',
#  ',',
#  'gil',
#  'fez',
#  'provocação',
#  'flamenguistas',
#  'pois',
#  'fluminense',
#  'acabado',
#  'ser',
#  'campeão',
#  '!',
#  '!',
#  '!',
#  '@universoffc',
#  '@fluminensefc',
#  '@fluminensefc',
#  '@dejesusofiicial',
#  '@igorjuliao2',
#  '@nene10',
#  '@oflumedomina',
#  '@brunohenrique',
#  '@universoffc',
#  '@fluminensefc',
#  '@fluminensefc',
#  '@nene10',
#  '@flamengo',
#  '@giorgiandea',
#  'amo',
#  'seleção',
#  '❤',
#  '️',
#  '@bezarrade',
#  '@paolo_crf',
#  '@gabigol',
#  '@ribasdiego10',
#  '@diegoalvesgol',
#  '@rcaio03',
#  '@evertonri',
#  '@r13_official',
#  '@flamengo',
#  '@brunohenrique',
#  '@yuripalopoli',
#  '@mlktete',
#  '@brunohenrique',
#  'kkkkkkk',
#  'goleiro',
#  'fluminense',
#  'chama',
#  'muriel',
#  '?',
#  'https://t.co/grc6cd8eew',
#  '@fluminensefc',
#  '@nene10',
#  '=',
#  'tudo',
#  'pra',
#  'mim',
#  '.',
#  '@victormatheusb7',
#  'var',
#  'quase',
#  'sempre',
#  'funciona',
#  'contra',
#  'fluminense',
#  'rs',
#  'sistema',
#  'foda',
#  '-',
#  '@phganso',
#  '@fredcruzeiro19',
#  '@ricarvalho_pc',
#  '@giorgiandea',
#  'existe',
#  'opinião',
#  'quanto',
#  'tratamento',
#  'rival',
#  '.',
#  'entendeu',
#  'agora',
#  'ex-funcionário',
#  'clube',
#  ',',
#  'agora',
#  'clube',
#  'rival',
#  'desenhar',
#  '?',
#  'agradecimentos',
#  'dados',
#  'agora',
#  'contra',
#  'cruzeiro',
#  '.',
#  '@territoriorn',
#  '@marcellocravo',
#  '@paolo_crf',
#  '@gabigol',
#  '@ribasdiego10',
#  '@diegoalvesgol',
#  '@rcaio03',
#  '@evertonri',
#  '@r13_official',
#  '@flamengo',
#  '@brunohenrique',
#  'entendi',
#  'resposta',
#  '?',
#  'vc',
#  'virada',
#  'contra',
#  'atlético',
#  'mineiro',
#  'flamengo',
#  'campeão',
#  'brasileiro',
#  'mundial',
#  '?',
#  'lá',
#  'muitos',
#  'outros',
#  'jogos',
#  'vi',
#  'time',
#  'ser',
#  'campeão',
#  'maracanã',
#  'moro',
#  'rio',
#  ',',
#  'tá',
#  '?',
#  '@giorgiandea',
#  'podia',
#  'pedir',
#  'ser',
#  'convocado',
#  'dessa',
#  'vez',
#  '...',
#  'assim',
#  'guerrero',
#  'fez',
#  '...',
#  'amistosos',
#  ',',
#  'apenas',
#  'amistosos',
#  '.',
#  '@cacaucottaluis',
#  '@marcosbrazrio',
#  'orienta',
#  'jogadores',
#  '...',
#  'cássio',
#  'escalou',
#  '@phganso',
#  '@cartolafc',
#  '.',
#  'outra',
#  'explicação',
#  '?',
#  '@bezarrade',
#  '@paolo_crf',
#  '@gabigol',
#  '@ribasdiego10',
#  '@diegoalvesgol',
#  '@rcaio03',
#  '@evertonri',
#  '@r13_official',
#  '@flamengo',
#  '@brunohenrique',
#  'po',
#  ',',
#  'desde',
#  '81',
#  'nunca',
#  'viu',
#  'perder',
#  '?',
#  'deve',
#  'ir',
#  '1',
#  'vez',
#  'lor',
#  'ano',
#  'entao',
#  'ne',
#  '?',
#  'kkkkkk',
#  'qlquer',
#  'jeito',
#  ',',
#  'boa',
#  'sorte',
#  '!',
#  'pra',
#  'ser',
#  'flamenguista',
#  'nao',
#  'ser',
#  'assim',
#  ',',
#  'quero',
#  '!',
#  '!',
#  '!',
#  'kkk',
#  '@flamengo',
#  '@gabigol',
#  '@timeflamengo',
#  '@giorgiandea',
#  '@pretinhorodi',
#  '@ribasdiego10',
#  '@brunohenrique',
#  '@diegoalvesgol',
#  '@rcaio03',
#  '@pablomv5',
#  'https://t.co/a1x4kznbeh',
#  '@interaqui',
#  '@scinternacional',
#  '@copadobrasil',
#  '@gabigol',
#  '@brunohenrique',
#  '@giorgiandea',
#  'q',
#  'bom',
#  ',',
#  'pois',
#  'cara',
#  'leva',
#  'tudo',
#  'p',
#  'emoção',
#  'acaba',
#  'falando',
#  'merda',
#  'kkkkkk.senso',
#  '!',
#  '@universoffc',
#  '@fluminensefc',
#  '@fluminensefc',
#  '@dejesusofiicial',
#  '@phganso',
#  '@bezarrade',
#  '@gabigol',
#  '@ribasdiego10',
#  '@diegoalvesgol',
#  '@rcaio03',
#  '@evertonri',
#  '@r13_official',
#  '@flamengo',
#  '@brunohenrique',
#  'nunca',
#  'vi',
#  'flamengo',
#  'perder',
#  'vou',
#  'maracanã',
#  '#boladavez',
#  'queria',
#  'saber',
#  'dizer',
#  'sobre',
#  'jogo',
#  'flamengo',
#  'botafogo',
#  ',',
#  'onde',
#  'gabigol',
#  ',',
#  'rafinha',
#  'principalmente',
#  'coejar',
#  ',',
#  'terem',
#  'sidos',
#  'expulsos',
#  ',',
#  'principalmente',
#  'coejar',
#  'lance',
#  'sobre',
#  'marcinho',
#  ',',
#  'onde',
#  'var',
#  ',',
#  'viu',
#  'fez',
#  'nada',
#  '.',
#  '@simpraisa',
#  '@marcosbrazrio',
#  'preocupar',
#  'contratar',
#  'atacante',
#  'pra',
#  'fazer',
#  'sombra',
#  '@gabigol',
#  '@brunohenrique',
#  ',',
#  'rony',
#  'athletico',
#  'pr',
#  'ótimo',
#  'nome',
#  '!',
#  '!',
#  '@bezarrade',
#  '@paolo_crf',
#  '@gabigol',
#  '@ribasdiego10',
#  '@diegoalvesgol',
#  '@rcaio03',
#  '@evertonri',
#  '@r13_official',
#  '@flamengo',
#  '@brunohenrique',
#  '🍪',
#  '@bezarrade',
#  '@paolo_crf',
#  '@gabigol',
#  '@ribasdiego10',
#  '@diegoalvesgol',
#  '@rcaio03',
#  '@evertonri',
#  '@r13_official',
#  '@flamengo',
#  '@brunohenrique',
#  'rapaz',
#  '...',
#  '14',
#  'jogos',
#  'mengão',
#  'estádios',
#  'tbm',
#  'nunca',
#  'vi',
#  ...]

# %% [markdown]
# ## Removendo Menções

# %%
def removeMentions(tokens):
    mentions_regex = re.compile('[^@]')
    return list(filter(mentions_regex.match, tokens))

# %%
tokens_no_mentions = removeMentions(tokens_no_stopwords)

# %%
len(tokens_no_mentions)
# Out:
# 3346

# %%
tokens_no_mentions
# Out:
# ['podia',
#  'ter',
#  'ficado',
#  'calado',
#  '!',
#  'sabe',
#  'nada',
#  '!',
#  'ajudem',
#  'pé',
#  'quente',
#  ',',
#  'favor',
#  '❤',
#  '️',
#  '🖤',
#  'deus',
#  'kkkkk',
#  'veio',
#  'tomar',
#  'sopa',
#  'garfo',
#  ',',
#  'deu',
#  'nisso',
#  'aí',
#  'https://t.co/95gh5tcuk1',
#  'goleiro',
#  'muriel',
#  '32',
#  'anos',
#  ',',
#  'participou',
#  '12',
#  'jogos',
#  'fluminense',
#  'tomou',
#  'gol',
#  'três',
#  '.',
#  'corinthians',
#  '0',
#  'x',
#  '0',
#  'fluminense',
#  'fortaleza',
#  '0',
#  'x',
#  '1',
#  'fluminense',
#  'fluminense',
#  '1',
#  'x',
#  '0',
#  'fortaleza',
#  'fluminense',
#  'notícias',
#  'aqui',
#  '⤵',
#  '⤵',
#  '⤵',
#  'https://t.co/qym7buhl9m',
#  'https://t.co/jq2hiqybx9',
#  'síndrome',
#  'estocolmo',
#  '🤣',
#  '🤣',
#  '🤣',
#  'pqp',
#  'kkkkkk',
#  'tá',
#  'difícil',
#  'parar',
#  'coringa',
#  'flamengo',
#  ',',
#  'menino',
#  'jogo',
#  'mengão',
#  'torcida',
#  'show',
#  'pode',
#  'levantar',
#  'plaquinha',
#  'hj',
#  'gol',
#  '🔴',
#  '⚫',
#  '🔴',
#  '⚫',
#  '🔴',
#  '⚫',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  'dá',
#  'chapa',
#  'vola',
#  'kkkkkkkkkkkk',
#  'abraço',
#  'cara',
#  'durma',
#  'bem',
#  'q',
#  'jogar',
#  'lateral',
#  '.',
#  'manter',
#  'marcinho',
#  'meia',
#  'mandar',
#  'fernando',
#  'volta',
#  'pra',
#  'frança',
#  '.',
#  'vão',
#  'trazer',
#  'liberta',
#  'deixa',
#  'gente',
#  ',',
#  'so',
#  'vapo',
#  'vapo',
#  '🙅',
#  '🏻',
#  '\u200d',
#  '♂',
#  '️',
#  'sonho',
#  'ir',
#  'maraca',
#  'amigos',
#  'celebrar',
#  'vendo',
#  'flamengo',
#  'joga',
#  '!',
#  '!',
#  '!',
#  'nunca',
#  'maracanã',
#  'gostaria',
#  'realizar',
#  'sonho',
#  '!',
#  'quero',
#  'nada',
#  '!',
#  'quero',
#  'ver',
#  'flamengo',
#  'joga',
#  'sentir',
#  'emoção',
#  'maraca',
#  '!',
#  'ah',
#  'ta',
#  'kkk',
#  'achei',
#  'tava',
#  'dando',
#  'zicada',
#  'sei',
#  'la',
#  'kkkkkkkkk',
#  'ja',
#  'passeram',
#  'aqui',
#  'poa',
#  '.',
#  'enfim',
#  ',',
#  'elimina',
#  'gremio',
#  'ai',
#  'ta',
#  'tudo',
#  'certo',
#  'kkkkkkkkk',
#  'definição',
#  'pé',
#  'quente',
#  'pra',
#  'vc',
#  '?',
#  'dou',
#  'sorte',
#  ',',
#  'posso',
#  'fazer',
#  'vi',
#  'time',
#  'perder',
#  'trocentos',
#  'jogos',
#  '?',
#  'muitas',
#  'pessoas',
#  'jogos',
#  'viram',
#  'perder',
#  ',',
#  '🙏',
#  'vi',
#  '!',
#  'triste',
#  '!',
#  '!',
#  'desde',
#  '1981',
#  'nunca',
#  'vi',
#  'time',
#  'perder',
#  'maraca',
#  '!',
#  'sts',
#  'consegui',
#  'ingresso',
#  'pro',
#  'dia',
#  '23/10',
#  ',',
#  'pé',
#  'quente',
#  'vou',
#  'poder',
#  'ir',
#  '!',
#  'vcs',
#  'podem',
#  'ajudar',
#  '?',
#  'melhor',
#  'dizendo',
#  ',',
#  'adversário',
#  'chego',
#  'gol',
#  'fluminense',
#  ',',
#  'muriel',
#  'tá',
#  'destacando',
#  ',',
#  'odeio',
#  'treinador',
#  'medroso',
#  'medíocre',
#  'https://t.co/ajap6gfd3d',
#  'ver',
#  'renova',
#  'contrato',
#  'cm',
#  'marcinho',
#  'amadores',
#  ',',
#  'jeito',
#  'q',
#  'vão',
#  'deixar',
#  'sair',
#  'graça',
#  '.',
#  'q',
#  'jogou',
#  'baixo',
#  'liberta',
#  'postando',
#  'merda',
#  ',',
#  'kkkkk',
#  'fluminense',
#  'precisa',
#  'livrar',
#  'kelvin',
#  ',',
#  'ewandro',
#  ',',
#  'agenor',
#  ',',
#  'guilherme',
#  ',',
#  'brenner',
#  ',',
#  'digão',
#  ',',
#  'gilberto',
#  ',',
#  'daniel',
#  ',',
#  'airton',
#  ',',
#  'caio',
#  ',',
#  'pablo',
#  'dyego',
#  'dodi',
#  'pra',
#  '2020',
#  'urgente',
#  '.',
#  'menos',
#  'uns',
#  '500',
#  'mil',
#  'pagaria',
#  'jogador',
#  '100x',
#  'melhor',
#  'todos',
#  'juntos',
#  'bom',
#  'dia',
#  '❤',
#  '️',
#  '🖤',
#  'segue',
#  'líder',
#  'https://t.co/voqjpqhl53',
#  'https://t.co/ydtk8hugjv',
#  'timaço',
#  'po',
#  '%',
#  '#',
#  '#wednesdaywisdom',
#  '#flamengo',
#  '#flatv',
#  'https://t.co/sztcegzji0',
#  'acredito',
#  'vitória',
#  '!',
#  'time',
#  'precisa',
#  'mudar',
#  'atitude',
#  ',',
#  'gente',
#  'ainda',
#  'tenta',
#  'ficar',
#  'bola',
#  'estudo',
#  '.',
#  'acho',
#  'q',
#  'q',
#  'mudar',
#  'algumas',
#  'peças',
#  'q',
#  'olhar',
#  'p',
#  '/',
#  'banco',
#  'dê',
#  'medo',
#  '!',
#  'l.fernando',
#  'dose',
#  ',',
#  'ds7',
#  'dá',
#  'tirando',
#  'paciência',
#  ',',
#  'tão',
#  'cavando',
#  'qq',
#  'vaga',
#  'p',
#  '/',
#  'marcinho',
#  '!',
#  'bora',
#  'pra',
#  'praia',
#  'amanhã',
#  ',',
#  'peida',
#  '?',
#  'engraçado',
#  'pq',
#  'agora',
#  '?',
#  '?',
#  'pq',
#  'ano',
#  '?',
#  'ex',
#  ':',
#  '2',
#  ',',
#  '3',
#  'jogadores',
#  'convocados',
#  '#cbflixo',
#  'li',
#  'nenhuma',
#  'nota',
#  'neste',
#  'sentido',
#  '..',
#  'agora',
#  'pq',
#  'cheirinho',
#  'lá',
#  'vc',
#  'solta',
#  'dessa',
#  '!',
#  '!',
#  'nao',
#  'ofende',
#  'cara',
#  ',',
#  'agora',
#  'jogou',
#  'baixo',
#  'kkkkkkkk',
#  'todos',
#  'meses',
#  'consigo',
#  'ir',
#  ',',
#  'ainda',
#  'moro',
#  'rio',
#  ',',
#  'muitooooos',
#  'jogos',
#  ',',
#  'preciso',
#  'mentir',
#  ',',
#  'vi',
#  'flamengo',
#  'perder',
#  '.',
#  '#redacaosportv',
#  'música',
#  'gilberto',
#  'gil',
#  'homenagem',
#  'flamengo',
#  ',',
#  'contrário',
#  ',',
#  'tricolor',
#  ',',
#  'gil',
#  'fez',
#  'provocação',
#  'flamenguistas',
#  'pois',
#  'fluminense',
#  'acabado',
#  'ser',
#  'campeão',
#  '!',
#  '!',
#  '!',
#  'amo',
#  'seleção',
#  '❤',
#  '️',
#  'kkkkkkk',
#  'goleiro',
#  'fluminense',
#  'chama',
#  'muriel',
#  '?',
#  'https://t.co/grc6cd8eew',
#  '=',
#  'tudo',
#  'pra',
#  'mim',
#  '.',
#  'var',
#  'quase',
#  'sempre',
#  'funciona',
#  'contra',
#  'fluminense',
#  'rs',
#  'sistema',
#  'foda',
#  '-',
#  'existe',
#  'opinião',
#  'quanto',
#  'tratamento',
#  'rival',
#  '.',
#  'entendeu',
#  'agora',
#  'ex-funcionário',
#  'clube',
#  ',',
#  'agora',
#  'clube',
#  'rival',
#  'desenhar',
#  '?',
#  'agradecimentos',
#  'dados',
#  'agora',
#  'contra',
#  'cruzeiro',
#  '.',
#  'entendi',
#  'resposta',
#  '?',
#  'vc',
#  'virada',
#  'contra',
#  'atlético',
#  'mineiro',
#  'flamengo',
#  'campeão',
#  'brasileiro',
#  'mundial',
#  '?',
#  'lá',
#  'muitos',
#  'outros',
#  'jogos',
#  'vi',
#  'time',
#  'ser',
#  'campeão',
#  'maracanã',
#  'moro',
#  'rio',
#  ',',
#  'tá',
#  '?',
#  'podia',
#  'pedir',
#  'ser',
#  'convocado',
#  'dessa',
#  'vez',
#  '...',
#  'assim',
#  'guerrero',
#  'fez',
#  '...',
#  'amistosos',
#  ',',
#  'apenas',
#  'amistosos',
#  '.',
#  'orienta',
#  'jogadores',
#  '...',
#  'cássio',
#  'escalou',
#  '.',
#  'outra',
#  'explicação',
#  '?',
#  'po',
#  ',',
#  'desde',
#  '81',
#  'nunca',
#  'viu',
#  'perder',
#  '?',
#  'deve',
#  'ir',
#  '1',
#  'vez',
#  'lor',
#  'ano',
#  'entao',
#  'ne',
#  '?',
#  'kkkkkk',
#  'qlquer',
#  'jeito',
#  ',',
#  'boa',
#  'sorte',
#  '!',
#  'pra',
#  'ser',
#  'flamenguista',
#  'nao',
#  'ser',
#  'assim',
#  ',',
#  'quero',
#  '!',
#  '!',
#  '!',
#  'kkk',
#  'https://t.co/a1x4kznbeh',
#  'q',
#  'bom',
#  ',',
#  'pois',
#  'cara',
#  'leva',
#  'tudo',
#  'p',
#  'emoção',
#  'acaba',
#  'falando',
#  'merda',
#  'kkkkkk.senso',
#  '!',
#  'nunca',
#  'vi',
#  'flamengo',
#  'perder',
#  'vou',
#  'maracanã',
#  '#boladavez',
#  'queria',
#  'saber',
#  'dizer',
#  'sobre',
#  'jogo',
#  'flamengo',
#  'botafogo',
#  ',',
#  'onde',
#  'gabigol',
#  ',',
#  'rafinha',
#  'principalmente',
#  'coejar',
#  ',',
#  'terem',
#  'sidos',
#  'expulsos',
#  ',',
#  'principalmente',
#  'coejar',
#  'lance',
#  'sobre',
#  'marcinho',
#  ',',
#  'onde',
#  'var',
#  ',',
#  'viu',
#  'fez',
#  'nada',
#  '.',
#  'preocupar',
#  'contratar',
#  'atacante',
#  'pra',
#  'fazer',
#  'sombra',
#  ',',
#  'rony',
#  'athletico',
#  'pr',
#  'ótimo',
#  'nome',
#  '!',
#  '!',
#  '🍪',
#  'rapaz',
#  '...',
#  '14',
#  'jogos',
#  'mengão',
#  'estádios',
#  'tbm',
#  'nunca',
#  'vi',
#  'perder',
#  '.',
#  '11',
#  'vitórias',
#  '3',
#  'empates',
#  '.',
#  'alô',
#  'puder',
#  'dar',
#  'rt',
#  'p',
#  'ajudar',
#  'achar',
#  'alguém',
#  'ingresso',
#  'poderá',
#  'ir',
#  '..',
#  "d'alessandro",
#  ',',
#  '"',
#  'falta',
#  '!',
#  '"',
#  'soberba',
#  'oba',
#  'oba',
#  'lado',
#  ',',
#  'agora',
#  'questão',
#  'honra',
#  'eliminar',
#  '.',
#  'https://t.co/nvg1ytd05b',
#  'aff',
#  ',',
#  'kkkkkk',
#  'coisa',
#  'linda',
#  '...',
#  'apaixonado',
#  '(',
#  'hetero',
#  ')',
#  '❤',
#  '️',
#  '🖤',
#  'pessoas',
#  'preferem',
#  'criticar',
#  'questionar',
#  'ajudar',
#  '!',
#  'brigadão',
#  'força',
#  '!',
#  '👏',
#  '👏',
#  '🖤',
#  '❤',
#  '️',
#  'caralho',
#  'vou',
#  'vestir',
#  'bh',
#  '27',
#  'qualquer',
#  'semelhança',
#  'mera',
#  'coincidência',
#  'amo',
#  'cara',
#  'recebe',
#  'clube',
#  '"',
#  'representa',
#  '"',
#  '.',
#  'barbaridade',
#  '!',
#  '!',
#  '!',
#  '😔',
#  '😔',
#  '😔',
#  'cada',
#  '.',
#  'botafogo',
#  'x',
#  'paulo',
#  'árbitro',
#  ':',
#  'jean',
#  'pierre',
#  'goncalves',
#  'lima',
#  '/',
#  'rs',
#  'árbitro',
#  'vídeo',
#  ':',
#  'andre',
#  'luiz',
#  'freitas',
#  'castro',
#  '/',
#  'go',
#  'pendurados',
#  'c',
#  '/',
#  '2',
#  'amarelos',
#  ':',
#  'marcinho',
#  ';',
#  'fernando',
#  ';',
#  'joel',
#  'carli',
#  ';',
#  'marcelo',
#  ';',
#  'gilson',
#  ';',
#  'gustavo',
#  ';',
#  'alex',
#  'santana',
#  ';',
#  'léo',
#  'valencia',
#  ';',
#  'pimpão',
#  ';',
#  'luiz',
#  'fernando',
#  '.',
#  'olha',
#  'lindo',
#  'nação',
#  'rubro',
#  'negra',
#  'https://t.co/zhmfywx1m7',
#  '📺',
#  '📺',
#  '📺',
#  '70',
#  'mil',
#  'pessoas',
#  '.',
#  'negócio',
#  'pé',
#  'quente',
#  '/',
#  'pé',
#  'frio',
#  'faz',
#  'menor',
#  'sentido',
#  ',',
#  'zoeira',
#  '.',
#  'boa',
#  'noite',
#  ',',
#  'pronto',
#  'pra',
#  'descansar',
#  'ja',
#  '?',
#  'esquece',
#  'amo',
#  'copa',
#  'brasil',
#  'artilheiros',
#  'pipico',
#  '(',
#  'santa',
#  'cruz',
#  ')',
#  '5',
#  'luciano',
#  '(',
#  'grêmio',
#  ')',
#  '(',
#  ')',
#  '5',
#  'guerrero',
#  '(',
#  'internacional',
#  ')',
#  '5',
#  'daniel',
#  'amorim',
#  '(',
#  'avaí',
#  ')',
#  '4',
#  'gilberto',
#  '(',
#  'bahia',
#  ')',
#  '4',
#  'carlos',
#  'sánchez',
#  '(',
#  'santos',
#  ')',
#  '4',
#  'nando',
#  '(',
#  'guarani',
#  ')',
#  '(',
#  'b',
#  ')',
#  '4',
#  '(',
#  ')',
#  'gols',
#  'marcados',
#  'fluminense',
#  '(',
#  'b',
#  ')',
#  'gols',
#  'marcados',
#  'botafogo-pb',
#  '#finalcopadobrasil',
#  'https://t.co/uaxsesmbc7',
#  'dá',
#  'olhada',
#  'nisso',
#  'aqui',
#  ',',
#  'rapidin',
#  'toda',
#  'soberba',
#  'castigada',
#  '!',
#  'srn',
#  '.',
#  'sonhei',
#  'fazia',
#  'churrascada',
#  'aqui',
#  'casa',
#  ',',
#  'chave',
#  'portão',
#  'cr',
#  'kkkkkkkkkkkkkkkkkk',
#  'cara',
#  'gremista',
#  'colorado',
#  ',',
#  'pode',
#  'arnaldo',
#  '?',
#  '?',
#  '?',
#  'kkkk',
#  'bom',
#  ',',
#  'vc',
#  'ofendeu',
#  'fala',
#  ',',
#  'porque',
#  'pau',
#  'representa',
#  'akkkkkkkkk',
#  'fim',
#  'jogo',
#  ',',
#  'fluminense',
#  ...]

# %%
def removeLinks(tokens):
    links_regex = re.compile('^(?!http).*')
    return list(filter(links_regex.match, tokens))

# %% [markdown]
# ## Removendo links

# %%
tokens_no_links = removeLinks(tokens_no_mentions)

# %%
len(tokens_no_links)
# Out:
# 3299

# %%
tokens_no_links
# Out:
# ['podia',
#  'ter',
#  'ficado',
#  'calado',
#  '!',
#  'sabe',
#  'nada',
#  '!',
#  'ajudem',
#  'pé',
#  'quente',
#  ',',
#  'favor',
#  '❤',
#  '️',
#  '🖤',
#  'deus',
#  'kkkkk',
#  'veio',
#  'tomar',
#  'sopa',
#  'garfo',
#  ',',
#  'deu',
#  'nisso',
#  'aí',
#  'goleiro',
#  'muriel',
#  '32',
#  'anos',
#  ',',
#  'participou',
#  '12',
#  'jogos',
#  'fluminense',
#  'tomou',
#  'gol',
#  'três',
#  '.',
#  'corinthians',
#  '0',
#  'x',
#  '0',
#  'fluminense',
#  'fortaleza',
#  '0',
#  'x',
#  '1',
#  'fluminense',
#  'fluminense',
#  '1',
#  'x',
#  '0',
#  'fortaleza',
#  'fluminense',
#  'notícias',
#  'aqui',
#  '⤵',
#  '⤵',
#  '⤵',
#  'síndrome',
#  'estocolmo',
#  '🤣',
#  '🤣',
#  '🤣',
#  'pqp',
#  'kkkkkk',
#  'tá',
#  'difícil',
#  'parar',
#  'coringa',
#  'flamengo',
#  ',',
#  'menino',
#  'jogo',
#  'mengão',
#  'torcida',
#  'show',
#  'pode',
#  'levantar',
#  'plaquinha',
#  'hj',
#  'gol',
#  '🔴',
#  '⚫',
#  '🔴',
#  '⚫',
#  '🔴',
#  '⚫',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  'dá',
#  'chapa',
#  'vola',
#  'kkkkkkkkkkkk',
#  'abraço',
#  'cara',
#  'durma',
#  'bem',
#  'q',
#  'jogar',
#  'lateral',
#  '.',
#  'manter',
#  'marcinho',
#  'meia',
#  'mandar',
#  'fernando',
#  'volta',
#  'pra',
#  'frança',
#  '.',
#  'vão',
#  'trazer',
#  'liberta',
#  'deixa',
#  'gente',
#  ',',
#  'so',
#  'vapo',
#  'vapo',
#  '🙅',
#  '🏻',
#  '\u200d',
#  '♂',
#  '️',
#  'sonho',
#  'ir',
#  'maraca',
#  'amigos',
#  'celebrar',
#  'vendo',
#  'flamengo',
#  'joga',
#  '!',
#  '!',
#  '!',
#  'nunca',
#  'maracanã',
#  'gostaria',
#  'realizar',
#  'sonho',
#  '!',
#  'quero',
#  'nada',
#  '!',
#  'quero',
#  'ver',
#  'flamengo',
#  'joga',
#  'sentir',
#  'emoção',
#  'maraca',
#  '!',
#  'ah',
#  'ta',
#  'kkk',
#  'achei',
#  'tava',
#  'dando',
#  'zicada',
#  'sei',
#  'la',
#  'kkkkkkkkk',
#  'ja',
#  'passeram',
#  'aqui',
#  'poa',
#  '.',
#  'enfim',
#  ',',
#  'elimina',
#  'gremio',
#  'ai',
#  'ta',
#  'tudo',
#  'certo',
#  'kkkkkkkkk',
#  'definição',
#  'pé',
#  'quente',
#  'pra',
#  'vc',
#  '?',
#  'dou',
#  'sorte',
#  ',',
#  'posso',
#  'fazer',
#  'vi',
#  'time',
#  'perder',
#  'trocentos',
#  'jogos',
#  '?',
#  'muitas',
#  'pessoas',
#  'jogos',
#  'viram',
#  'perder',
#  ',',
#  '🙏',
#  'vi',
#  '!',
#  'triste',
#  '!',
#  '!',
#  'desde',
#  '1981',
#  'nunca',
#  'vi',
#  'time',
#  'perder',
#  'maraca',
#  '!',
#  'sts',
#  'consegui',
#  'ingresso',
#  'pro',
#  'dia',
#  '23/10',
#  ',',
#  'pé',
#  'quente',
#  'vou',
#  'poder',
#  'ir',
#  '!',
#  'vcs',
#  'podem',
#  'ajudar',
#  '?',
#  'melhor',
#  'dizendo',
#  ',',
#  'adversário',
#  'chego',
#  'gol',
#  'fluminense',
#  ',',
#  'muriel',
#  'tá',
#  'destacando',
#  ',',
#  'odeio',
#  'treinador',
#  'medroso',
#  'medíocre',
#  'ver',
#  'renova',
#  'contrato',
#  'cm',
#  'marcinho',
#  'amadores',
#  ',',
#  'jeito',
#  'q',
#  'vão',
#  'deixar',
#  'sair',
#  'graça',
#  '.',
#  'q',
#  'jogou',
#  'baixo',
#  'liberta',
#  'postando',
#  'merda',
#  ',',
#  'kkkkk',
#  'fluminense',
#  'precisa',
#  'livrar',
#  'kelvin',
#  ',',
#  'ewandro',
#  ',',
#  'agenor',
#  ',',
#  'guilherme',
#  ',',
#  'brenner',
#  ',',
#  'digão',
#  ',',
#  'gilberto',
#  ',',
#  'daniel',
#  ',',
#  'airton',
#  ',',
#  'caio',
#  ',',
#  'pablo',
#  'dyego',
#  'dodi',
#  'pra',
#  '2020',
#  'urgente',
#  '.',
#  'menos',
#  'uns',
#  '500',
#  'mil',
#  'pagaria',
#  'jogador',
#  '100x',
#  'melhor',
#  'todos',
#  'juntos',
#  'bom',
#  'dia',
#  '❤',
#  '️',
#  '🖤',
#  'segue',
#  'líder',
#  'timaço',
#  'po',
#  '%',
#  '#',
#  '#wednesdaywisdom',
#  '#flamengo',
#  '#flatv',
#  'acredito',
#  'vitória',
#  '!',
#  'time',
#  'precisa',
#  'mudar',
#  'atitude',
#  ',',
#  'gente',
#  'ainda',
#  'tenta',
#  'ficar',
#  'bola',
#  'estudo',
#  '.',
#  'acho',
#  'q',
#  'q',
#  'mudar',
#  'algumas',
#  'peças',
#  'q',
#  'olhar',
#  'p',
#  '/',
#  'banco',
#  'dê',
#  'medo',
#  '!',
#  'l.fernando',
#  'dose',
#  ',',
#  'ds7',
#  'dá',
#  'tirando',
#  'paciência',
#  ',',
#  'tão',
#  'cavando',
#  'qq',
#  'vaga',
#  'p',
#  '/',
#  'marcinho',
#  '!',
#  'bora',
#  'pra',
#  'praia',
#  'amanhã',
#  ',',
#  'peida',
#  '?',
#  'engraçado',
#  'pq',
#  'agora',
#  '?',
#  '?',
#  'pq',
#  'ano',
#  '?',
#  'ex',
#  ':',
#  '2',
#  ',',
#  '3',
#  'jogadores',
#  'convocados',
#  '#cbflixo',
#  'li',
#  'nenhuma',
#  'nota',
#  'neste',
#  'sentido',
#  '..',
#  'agora',
#  'pq',
#  'cheirinho',
#  'lá',
#  'vc',
#  'solta',
#  'dessa',
#  '!',
#  '!',
#  'nao',
#  'ofende',
#  'cara',
#  ',',
#  'agora',
#  'jogou',
#  'baixo',
#  'kkkkkkkk',
#  'todos',
#  'meses',
#  'consigo',
#  'ir',
#  ',',
#  'ainda',
#  'moro',
#  'rio',
#  ',',
#  'muitooooos',
#  'jogos',
#  ',',
#  'preciso',
#  'mentir',
#  ',',
#  'vi',
#  'flamengo',
#  'perder',
#  '.',
#  '#redacaosportv',
#  'música',
#  'gilberto',
#  'gil',
#  'homenagem',
#  'flamengo',
#  ',',
#  'contrário',
#  ',',
#  'tricolor',
#  ',',
#  'gil',
#  'fez',
#  'provocação',
#  'flamenguistas',
#  'pois',
#  'fluminense',
#  'acabado',
#  'ser',
#  'campeão',
#  '!',
#  '!',
#  '!',
#  'amo',
#  'seleção',
#  '❤',
#  '️',
#  'kkkkkkk',
#  'goleiro',
#  'fluminense',
#  'chama',
#  'muriel',
#  '?',
#  '=',
#  'tudo',
#  'pra',
#  'mim',
#  '.',
#  'var',
#  'quase',
#  'sempre',
#  'funciona',
#  'contra',
#  'fluminense',
#  'rs',
#  'sistema',
#  'foda',
#  '-',
#  'existe',
#  'opinião',
#  'quanto',
#  'tratamento',
#  'rival',
#  '.',
#  'entendeu',
#  'agora',
#  'ex-funcionário',
#  'clube',
#  ',',
#  'agora',
#  'clube',
#  'rival',
#  'desenhar',
#  '?',
#  'agradecimentos',
#  'dados',
#  'agora',
#  'contra',
#  'cruzeiro',
#  '.',
#  'entendi',
#  'resposta',
#  '?',
#  'vc',
#  'virada',
#  'contra',
#  'atlético',
#  'mineiro',
#  'flamengo',
#  'campeão',
#  'brasileiro',
#  'mundial',
#  '?',
#  'lá',
#  'muitos',
#  'outros',
#  'jogos',
#  'vi',
#  'time',
#  'ser',
#  'campeão',
#  'maracanã',
#  'moro',
#  'rio',
#  ',',
#  'tá',
#  '?',
#  'podia',
#  'pedir',
#  'ser',
#  'convocado',
#  'dessa',
#  'vez',
#  '...',
#  'assim',
#  'guerrero',
#  'fez',
#  '...',
#  'amistosos',
#  ',',
#  'apenas',
#  'amistosos',
#  '.',
#  'orienta',
#  'jogadores',
#  '...',
#  'cássio',
#  'escalou',
#  '.',
#  'outra',
#  'explicação',
#  '?',
#  'po',
#  ',',
#  'desde',
#  '81',
#  'nunca',
#  'viu',
#  'perder',
#  '?',
#  'deve',
#  'ir',
#  '1',
#  'vez',
#  'lor',
#  'ano',
#  'entao',
#  'ne',
#  '?',
#  'kkkkkk',
#  'qlquer',
#  'jeito',
#  ',',
#  'boa',
#  'sorte',
#  '!',
#  'pra',
#  'ser',
#  'flamenguista',
#  'nao',
#  'ser',
#  'assim',
#  ',',
#  'quero',
#  '!',
#  '!',
#  '!',
#  'kkk',
#  'q',
#  'bom',
#  ',',
#  'pois',
#  'cara',
#  'leva',
#  'tudo',
#  'p',
#  'emoção',
#  'acaba',
#  'falando',
#  'merda',
#  'kkkkkk.senso',
#  '!',
#  'nunca',
#  'vi',
#  'flamengo',
#  'perder',
#  'vou',
#  'maracanã',
#  '#boladavez',
#  'queria',
#  'saber',
#  'dizer',
#  'sobre',
#  'jogo',
#  'flamengo',
#  'botafogo',
#  ',',
#  'onde',
#  'gabigol',
#  ',',
#  'rafinha',
#  'principalmente',
#  'coejar',
#  ',',
#  'terem',
#  'sidos',
#  'expulsos',
#  ',',
#  'principalmente',
#  'coejar',
#  'lance',
#  'sobre',
#  'marcinho',
#  ',',
#  'onde',
#  'var',
#  ',',
#  'viu',
#  'fez',
#  'nada',
#  '.',
#  'preocupar',
#  'contratar',
#  'atacante',
#  'pra',
#  'fazer',
#  'sombra',
#  ',',
#  'rony',
#  'athletico',
#  'pr',
#  'ótimo',
#  'nome',
#  '!',
#  '!',
#  '🍪',
#  'rapaz',
#  '...',
#  '14',
#  'jogos',
#  'mengão',
#  'estádios',
#  'tbm',
#  'nunca',
#  'vi',
#  'perder',
#  '.',
#  '11',
#  'vitórias',
#  '3',
#  'empates',
#  '.',
#  'alô',
#  'puder',
#  'dar',
#  'rt',
#  'p',
#  'ajudar',
#  'achar',
#  'alguém',
#  'ingresso',
#  'poderá',
#  'ir',
#  '..',
#  "d'alessandro",
#  ',',
#  '"',
#  'falta',
#  '!',
#  '"',
#  'soberba',
#  'oba',
#  'oba',
#  'lado',
#  ',',
#  'agora',
#  'questão',
#  'honra',
#  'eliminar',
#  '.',
#  'aff',
#  ',',
#  'kkkkkk',
#  'coisa',
#  'linda',
#  '...',
#  'apaixonado',
#  '(',
#  'hetero',
#  ')',
#  '❤',
#  '️',
#  '🖤',
#  'pessoas',
#  'preferem',
#  'criticar',
#  'questionar',
#  'ajudar',
#  '!',
#  'brigadão',
#  'força',
#  '!',
#  '👏',
#  '👏',
#  '🖤',
#  '❤',
#  '️',
#  'caralho',
#  'vou',
#  'vestir',
#  'bh',
#  '27',
#  'qualquer',
#  'semelhança',
#  'mera',
#  'coincidência',
#  'amo',
#  'cara',
#  'recebe',
#  'clube',
#  '"',
#  'representa',
#  '"',
#  '.',
#  'barbaridade',
#  '!',
#  '!',
#  '!',
#  '😔',
#  '😔',
#  '😔',
#  'cada',
#  '.',
#  'botafogo',
#  'x',
#  'paulo',
#  'árbitro',
#  ':',
#  'jean',
#  'pierre',
#  'goncalves',
#  'lima',
#  '/',
#  'rs',
#  'árbitro',
#  'vídeo',
#  ':',
#  'andre',
#  'luiz',
#  'freitas',
#  'castro',
#  '/',
#  'go',
#  'pendurados',
#  'c',
#  '/',
#  '2',
#  'amarelos',
#  ':',
#  'marcinho',
#  ';',
#  'fernando',
#  ';',
#  'joel',
#  'carli',
#  ';',
#  'marcelo',
#  ';',
#  'gilson',
#  ';',
#  'gustavo',
#  ';',
#  'alex',
#  'santana',
#  ';',
#  'léo',
#  'valencia',
#  ';',
#  'pimpão',
#  ';',
#  'luiz',
#  'fernando',
#  '.',
#  'olha',
#  'lindo',
#  'nação',
#  'rubro',
#  'negra',
#  '📺',
#  '📺',
#  '📺',
#  '70',
#  'mil',
#  'pessoas',
#  '.',
#  'negócio',
#  'pé',
#  'quente',
#  '/',
#  'pé',
#  'frio',
#  'faz',
#  'menor',
#  'sentido',
#  ',',
#  'zoeira',
#  '.',
#  'boa',
#  'noite',
#  ',',
#  'pronto',
#  'pra',
#  'descansar',
#  'ja',
#  '?',
#  'esquece',
#  'amo',
#  'copa',
#  'brasil',
#  'artilheiros',
#  'pipico',
#  '(',
#  'santa',
#  'cruz',
#  ')',
#  '5',
#  'luciano',
#  '(',
#  'grêmio',
#  ')',
#  '(',
#  ')',
#  '5',
#  'guerrero',
#  '(',
#  'internacional',
#  ')',
#  '5',
#  'daniel',
#  'amorim',
#  '(',
#  'avaí',
#  ')',
#  '4',
#  'gilberto',
#  '(',
#  'bahia',
#  ')',
#  '4',
#  'carlos',
#  'sánchez',
#  '(',
#  'santos',
#  ')',
#  '4',
#  'nando',
#  '(',
#  'guarani',
#  ')',
#  '(',
#  'b',
#  ')',
#  '4',
#  '(',
#  ')',
#  'gols',
#  'marcados',
#  'fluminense',
#  '(',
#  'b',
#  ')',
#  'gols',
#  'marcados',
#  'botafogo-pb',
#  '#finalcopadobrasil',
#  'dá',
#  'olhada',
#  'nisso',
#  'aqui',
#  ',',
#  'rapidin',
#  'toda',
#  'soberba',
#  'castigada',
#  '!',
#  'srn',
#  '.',
#  'sonhei',
#  'fazia',
#  'churrascada',
#  'aqui',
#  'casa',
#  ',',
#  'chave',
#  'portão',
#  'cr',
#  'kkkkkkkkkkkkkkkkkk',
#  'cara',
#  'gremista',
#  'colorado',
#  ',',
#  'pode',
#  'arnaldo',
#  '?',
#  '?',
#  '?',
#  'kkkk',
#  'bom',
#  ',',
#  'vc',
#  'ofendeu',
#  'fala',
#  ',',
#  'porque',
#  'pau',
#  'representa',
#  'akkkkkkkkk',
#  'fim',
#  'jogo',
#  ',',
#  'fluminense',
#  '1x0',
#  'corinthians',
#  '.',
#  'possivelmente',
#  'pior',
#  'atuação',
#  'vida',
#  'gilberto',
#  '.',
#  'chega',
#  'vestiário',
#  ',',
#  ...]

# %% [markdown]
# ## Removendo Números e placares

# %%
def removeNumbersAndScores(tokens):
    numbers_regex = re.compile('(([0-9]x[0-9])|(^x$)|(^[0-9]+$))')
    return [token for token in tokens if token not in list(filter(numbers_regex.match, tokens))]

# %%
tokens_no_numbers_scores = removeNumbersAndScores(tokens_no_links)

# %%
len(tokens_no_numbers_scores)
# Out:
# 3229

# %%
tokens_no_numbers_scores
# Out:
# ['podia',
#  'ter',
#  'ficado',
#  'calado',
#  '!',
#  'sabe',
#  'nada',
#  '!',
#  'ajudem',
#  'pé',
#  'quente',
#  ',',
#  'favor',
#  '❤',
#  '️',
#  '🖤',
#  'deus',
#  'kkkkk',
#  'veio',
#  'tomar',
#  'sopa',
#  'garfo',
#  ',',
#  'deu',
#  'nisso',
#  'aí',
#  'goleiro',
#  'muriel',
#  'anos',
#  ',',
#  'participou',
#  'jogos',
#  'fluminense',
#  'tomou',
#  'gol',
#  'três',
#  '.',
#  'corinthians',
#  'fluminense',
#  'fortaleza',
#  'fluminense',
#  'fluminense',
#  'fortaleza',
#  'fluminense',
#  'notícias',
#  'aqui',
#  '⤵',
#  '⤵',
#  '⤵',
#  'síndrome',
#  'estocolmo',
#  '🤣',
#  '🤣',
#  '🤣',
#  'pqp',
#  'kkkkkk',
#  'tá',
#  'difícil',
#  'parar',
#  'coringa',
#  'flamengo',
#  ',',
#  'menino',
#  'jogo',
#  'mengão',
#  'torcida',
#  'show',
#  'pode',
#  'levantar',
#  'plaquinha',
#  'hj',
#  'gol',
#  '🔴',
#  '⚫',
#  '🔴',
#  '⚫',
#  '🔴',
#  '⚫',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  'dá',
#  'chapa',
#  'vola',
#  'kkkkkkkkkkkk',
#  'abraço',
#  'cara',
#  'durma',
#  'bem',
#  'q',
#  'jogar',
#  'lateral',
#  '.',
#  'manter',
#  'marcinho',
#  'meia',
#  'mandar',
#  'fernando',
#  'volta',
#  'pra',
#  'frança',
#  '.',
#  'vão',
#  'trazer',
#  'liberta',
#  'deixa',
#  'gente',
#  ',',
#  'so',
#  'vapo',
#  'vapo',
#  '🙅',
#  '🏻',
#  '\u200d',
#  '♂',
#  '️',
#  'sonho',
#  'ir',
#  'maraca',
#  'amigos',
#  'celebrar',
#  'vendo',
#  'flamengo',
#  'joga',
#  '!',
#  '!',
#  '!',
#  'nunca',
#  'maracanã',
#  'gostaria',
#  'realizar',
#  'sonho',
#  '!',
#  'quero',
#  'nada',
#  '!',
#  'quero',
#  'ver',
#  'flamengo',
#  'joga',
#  'sentir',
#  'emoção',
#  'maraca',
#  '!',
#  'ah',
#  'ta',
#  'kkk',
#  'achei',
#  'tava',
#  'dando',
#  'zicada',
#  'sei',
#  'la',
#  'kkkkkkkkk',
#  'ja',
#  'passeram',
#  'aqui',
#  'poa',
#  '.',
#  'enfim',
#  ',',
#  'elimina',
#  'gremio',
#  'ai',
#  'ta',
#  'tudo',
#  'certo',
#  'kkkkkkkkk',
#  'definição',
#  'pé',
#  'quente',
#  'pra',
#  'vc',
#  '?',
#  'dou',
#  'sorte',
#  ',',
#  'posso',
#  'fazer',
#  'vi',
#  'time',
#  'perder',
#  'trocentos',
#  'jogos',
#  '?',
#  'muitas',
#  'pessoas',
#  'jogos',
#  'viram',
#  'perder',
#  ',',
#  '🙏',
#  'vi',
#  '!',
#  'triste',
#  '!',
#  '!',
#  'desde',
#  'nunca',
#  'vi',
#  'time',
#  'perder',
#  'maraca',
#  '!',
#  'sts',
#  'consegui',
#  'ingresso',
#  'pro',
#  'dia',
#  '23/10',
#  ',',
#  'pé',
#  'quente',
#  'vou',
#  'poder',
#  'ir',
#  '!',
#  'vcs',
#  'podem',
#  'ajudar',
#  '?',
#  'melhor',
#  'dizendo',
#  ',',
#  'adversário',
#  'chego',
#  'gol',
#  'fluminense',
#  ',',
#  'muriel',
#  'tá',
#  'destacando',
#  ',',
#  'odeio',
#  'treinador',
#  'medroso',
#  'medíocre',
#  'ver',
#  'renova',
#  'contrato',
#  'cm',
#  'marcinho',
#  'amadores',
#  ',',
#  'jeito',
#  'q',
#  'vão',
#  'deixar',
#  'sair',
#  'graça',
#  '.',
#  'q',
#  'jogou',
#  'baixo',
#  'liberta',
#  'postando',
#  'merda',
#  ',',
#  'kkkkk',
#  'fluminense',
#  'precisa',
#  'livrar',
#  'kelvin',
#  ',',
#  'ewandro',
#  ',',
#  'agenor',
#  ',',
#  'guilherme',
#  ',',
#  'brenner',
#  ',',
#  'digão',
#  ',',
#  'gilberto',
#  ',',
#  'daniel',
#  ',',
#  'airton',
#  ',',
#  'caio',
#  ',',
#  'pablo',
#  'dyego',
#  'dodi',
#  'pra',
#  'urgente',
#  '.',
#  'menos',
#  'uns',
#  'mil',
#  'pagaria',
#  'jogador',
#  '100x',
#  'melhor',
#  'todos',
#  'juntos',
#  'bom',
#  'dia',
#  '❤',
#  '️',
#  '🖤',
#  'segue',
#  'líder',
#  'timaço',
#  'po',
#  '%',
#  '#',
#  '#wednesdaywisdom',
#  '#flamengo',
#  '#flatv',
#  'acredito',
#  'vitória',
#  '!',
#  'time',
#  'precisa',
#  'mudar',
#  'atitude',
#  ',',
#  'gente',
#  'ainda',
#  'tenta',
#  'ficar',
#  'bola',
#  'estudo',
#  '.',
#  'acho',
#  'q',
#  'q',
#  'mudar',
#  'algumas',
#  'peças',
#  'q',
#  'olhar',
#  'p',
#  '/',
#  'banco',
#  'dê',
#  'medo',
#  '!',
#  'l.fernando',
#  'dose',
#  ',',
#  'ds7',
#  'dá',
#  'tirando',
#  'paciência',
#  ',',
#  'tão',
#  'cavando',
#  'qq',
#  'vaga',
#  'p',
#  '/',
#  'marcinho',
#  '!',
#  'bora',
#  'pra',
#  'praia',
#  'amanhã',
#  ',',
#  'peida',
#  '?',
#  'engraçado',
#  'pq',
#  'agora',
#  '?',
#  '?',
#  'pq',
#  'ano',
#  '?',
#  'ex',
#  ':',
#  ',',
#  'jogadores',
#  'convocados',
#  '#cbflixo',
#  'li',
#  'nenhuma',
#  'nota',
#  'neste',
#  'sentido',
#  '..',
#  'agora',
#  'pq',
#  'cheirinho',
#  'lá',
#  'vc',
#  'solta',
#  'dessa',
#  '!',
#  '!',
#  'nao',
#  'ofende',
#  'cara',
#  ',',
#  'agora',
#  'jogou',
#  'baixo',
#  'kkkkkkkk',
#  'todos',
#  'meses',
#  'consigo',
#  'ir',
#  ',',
#  'ainda',
#  'moro',
#  'rio',
#  ',',
#  'muitooooos',
#  'jogos',
#  ',',
#  'preciso',
#  'mentir',
#  ',',
#  'vi',
#  'flamengo',
#  'perder',
#  '.',
#  '#redacaosportv',
#  'música',
#  'gilberto',
#  'gil',
#  'homenagem',
#  'flamengo',
#  ',',
#  'contrário',
#  ',',
#  'tricolor',
#  ',',
#  'gil',
#  'fez',
#  'provocação',
#  'flamenguistas',
#  'pois',
#  'fluminense',
#  'acabado',
#  'ser',
#  'campeão',
#  '!',
#  '!',
#  '!',
#  'amo',
#  'seleção',
#  '❤',
#  '️',
#  'kkkkkkk',
#  'goleiro',
#  'fluminense',
#  'chama',
#  'muriel',
#  '?',
#  '=',
#  'tudo',
#  'pra',
#  'mim',
#  '.',
#  'var',
#  'quase',
#  'sempre',
#  'funciona',
#  'contra',
#  'fluminense',
#  'rs',
#  'sistema',
#  'foda',
#  '-',
#  'existe',
#  'opinião',
#  'quanto',
#  'tratamento',
#  'rival',
#  '.',
#  'entendeu',
#  'agora',
#  'ex-funcionário',
#  'clube',
#  ',',
#  'agora',
#  'clube',
#  'rival',
#  'desenhar',
#  '?',
#  'agradecimentos',
#  'dados',
#  'agora',
#  'contra',
#  'cruzeiro',
#  '.',
#  'entendi',
#  'resposta',
#  '?',
#  'vc',
#  'virada',
#  'contra',
#  'atlético',
#  'mineiro',
#  'flamengo',
#  'campeão',
#  'brasileiro',
#  'mundial',
#  '?',
#  'lá',
#  'muitos',
#  'outros',
#  'jogos',
#  'vi',
#  'time',
#  'ser',
#  'campeão',
#  'maracanã',
#  'moro',
#  'rio',
#  ',',
#  'tá',
#  '?',
#  'podia',
#  'pedir',
#  'ser',
#  'convocado',
#  'dessa',
#  'vez',
#  '...',
#  'assim',
#  'guerrero',
#  'fez',
#  '...',
#  'amistosos',
#  ',',
#  'apenas',
#  'amistosos',
#  '.',
#  'orienta',
#  'jogadores',
#  '...',
#  'cássio',
#  'escalou',
#  '.',
#  'outra',
#  'explicação',
#  '?',
#  'po',
#  ',',
#  'desde',
#  'nunca',
#  'viu',
#  'perder',
#  '?',
#  'deve',
#  'ir',
#  'vez',
#  'lor',
#  'ano',
#  'entao',
#  'ne',
#  '?',
#  'kkkkkk',
#  'qlquer',
#  'jeito',
#  ',',
#  'boa',
#  'sorte',
#  '!',
#  'pra',
#  'ser',
#  'flamenguista',
#  'nao',
#  'ser',
#  'assim',
#  ',',
#  'quero',
#  '!',
#  '!',
#  '!',
#  'kkk',
#  'q',
#  'bom',
#  ',',
#  'pois',
#  'cara',
#  'leva',
#  'tudo',
#  'p',
#  'emoção',
#  'acaba',
#  'falando',
#  'merda',
#  'kkkkkk.senso',
#  '!',
#  'nunca',
#  'vi',
#  'flamengo',
#  'perder',
#  'vou',
#  'maracanã',
#  '#boladavez',
#  'queria',
#  'saber',
#  'dizer',
#  'sobre',
#  'jogo',
#  'flamengo',
#  'botafogo',
#  ',',
#  'onde',
#  'gabigol',
#  ',',
#  'rafinha',
#  'principalmente',
#  'coejar',
#  ',',
#  'terem',
#  'sidos',
#  'expulsos',
#  ',',
#  'principalmente',
#  'coejar',
#  'lance',
#  'sobre',
#  'marcinho',
#  ',',
#  'onde',
#  'var',
#  ',',
#  'viu',
#  'fez',
#  'nada',
#  '.',
#  'preocupar',
#  'contratar',
#  'atacante',
#  'pra',
#  'fazer',
#  'sombra',
#  ',',
#  'rony',
#  'athletico',
#  'pr',
#  'ótimo',
#  'nome',
#  '!',
#  '!',
#  '🍪',
#  'rapaz',
#  '...',
#  'jogos',
#  'mengão',
#  'estádios',
#  'tbm',
#  'nunca',
#  'vi',
#  'perder',
#  '.',
#  'vitórias',
#  'empates',
#  '.',
#  'alô',
#  'puder',
#  'dar',
#  'rt',
#  'p',
#  'ajudar',
#  'achar',
#  'alguém',
#  'ingresso',
#  'poderá',
#  'ir',
#  '..',
#  "d'alessandro",
#  ',',
#  '"',
#  'falta',
#  '!',
#  '"',
#  'soberba',
#  'oba',
#  'oba',
#  'lado',
#  ',',
#  'agora',
#  'questão',
#  'honra',
#  'eliminar',
#  '.',
#  'aff',
#  ',',
#  'kkkkkk',
#  'coisa',
#  'linda',
#  '...',
#  'apaixonado',
#  '(',
#  'hetero',
#  ')',
#  '❤',
#  '️',
#  '🖤',
#  'pessoas',
#  'preferem',
#  'criticar',
#  'questionar',
#  'ajudar',
#  '!',
#  'brigadão',
#  'força',
#  '!',
#  '👏',
#  '👏',
#  '🖤',
#  '❤',
#  '️',
#  'caralho',
#  'vou',
#  'vestir',
#  'bh',
#  'qualquer',
#  'semelhança',
#  'mera',
#  'coincidência',
#  'amo',
#  'cara',
#  'recebe',
#  'clube',
#  '"',
#  'representa',
#  '"',
#  '.',
#  'barbaridade',
#  '!',
#  '!',
#  '!',
#  '😔',
#  '😔',
#  '😔',
#  'cada',
#  '.',
#  'botafogo',
#  'paulo',
#  'árbitro',
#  ':',
#  'jean',
#  'pierre',
#  'goncalves',
#  'lima',
#  '/',
#  'rs',
#  'árbitro',
#  'vídeo',
#  ':',
#  'andre',
#  'luiz',
#  'freitas',
#  'castro',
#  '/',
#  'go',
#  'pendurados',
#  'c',
#  '/',
#  'amarelos',
#  ':',
#  'marcinho',
#  ';',
#  'fernando',
#  ';',
#  'joel',
#  'carli',
#  ';',
#  'marcelo',
#  ';',
#  'gilson',
#  ';',
#  'gustavo',
#  ';',
#  'alex',
#  'santana',
#  ';',
#  'léo',
#  'valencia',
#  ';',
#  'pimpão',
#  ';',
#  'luiz',
#  'fernando',
#  '.',
#  'olha',
#  'lindo',
#  'nação',
#  'rubro',
#  'negra',
#  '📺',
#  '📺',
#  '📺',
#  'mil',
#  'pessoas',
#  '.',
#  'negócio',
#  'pé',
#  'quente',
#  '/',
#  'pé',
#  'frio',
#  'faz',
#  'menor',
#  'sentido',
#  ',',
#  'zoeira',
#  '.',
#  'boa',
#  'noite',
#  ',',
#  'pronto',
#  'pra',
#  'descansar',
#  'ja',
#  '?',
#  'esquece',
#  'amo',
#  'copa',
#  'brasil',
#  'artilheiros',
#  'pipico',
#  '(',
#  'santa',
#  'cruz',
#  ')',
#  'luciano',
#  '(',
#  'grêmio',
#  ')',
#  '(',
#  ')',
#  'guerrero',
#  '(',
#  'internacional',
#  ')',
#  'daniel',
#  'amorim',
#  '(',
#  'avaí',
#  ')',
#  'gilberto',
#  '(',
#  'bahia',
#  ')',
#  'carlos',
#  'sánchez',
#  '(',
#  'santos',
#  ')',
#  'nando',
#  '(',
#  'guarani',
#  ')',
#  '(',
#  'b',
#  ')',
#  '(',
#  ')',
#  'gols',
#  'marcados',
#  'fluminense',
#  '(',
#  'b',
#  ')',
#  'gols',
#  'marcados',
#  'botafogo-pb',
#  '#finalcopadobrasil',
#  'dá',
#  'olhada',
#  'nisso',
#  'aqui',
#  ',',
#  'rapidin',
#  'toda',
#  'soberba',
#  'castigada',
#  '!',
#  'srn',
#  '.',
#  'sonhei',
#  'fazia',
#  'churrascada',
#  'aqui',
#  'casa',
#  ',',
#  'chave',
#  'portão',
#  'cr',
#  'kkkkkkkkkkkkkkkkkk',
#  'cara',
#  'gremista',
#  'colorado',
#  ',',
#  'pode',
#  'arnaldo',
#  '?',
#  '?',
#  '?',
#  'kkkk',
#  'bom',
#  ',',
#  'vc',
#  'ofendeu',
#  'fala',
#  ',',
#  'porque',
#  'pau',
#  'representa',
#  'akkkkkkkkk',
#  'fim',
#  'jogo',
#  ',',
#  'fluminense',
#  'corinthians',
#  '.',
#  'possivelmente',
#  'pior',
#  'atuação',
#  'vida',
#  'gilberto',
#  '.',
#  'chega',
#  'vestiário',
#  ',',
#  'oswaldo',
#  'oliveira',
#  'sorri',
#  'grita',
#  '"',
#  'gibaaaa',
#  'ganhou',
#  'todas',
#  '!',
#  '"',
#  'pra',
#  'internar',
#  'atestando',
#  'insanidade',
#  'oswaldo',
#  ',',
#  'boa',
#  '.',
#  '!',
#  'nunca',
#  'vi',
#  '!',
#  'vou',
#  'todos',
#  ',',
#  'muitos',
#  'jogos',
#  'flamengo',
#  'perdeu',
#  '!',
#  'tão',
#  'pouco',
#  'entrosados',
#  ...]

# %% [markdown]
# ## Remove Pontuação

# %%
def removePontuation(tokens):
    pontuation_regex = re.compile('[^!\.?:\[\],\{\}\\\/;"\(\)]')
    return list(filter(pontuation_regex.match, tokens))

# %%
tokens_no_pontuation = removePontuation(tokens_no_numbers_scores)

# %%
len(tokens_no_pontuation)
# Out:
# 2597

# %%
tokens_no_pontuation
# Out:
# ['podia',
#  'ter',
#  'ficado',
#  'calado',
#  'sabe',
#  'nada',
#  'ajudem',
#  'pé',
#  'quente',
#  'favor',
#  '❤',
#  '️',
#  '🖤',
#  'deus',
#  'kkkkk',
#  'veio',
#  'tomar',
#  'sopa',
#  'garfo',
#  'deu',
#  'nisso',
#  'aí',
#  'goleiro',
#  'muriel',
#  'anos',
#  'participou',
#  'jogos',
#  'fluminense',
#  'tomou',
#  'gol',
#  'três',
#  'corinthians',
#  'fluminense',
#  'fortaleza',
#  'fluminense',
#  'fluminense',
#  'fortaleza',
#  'fluminense',
#  'notícias',
#  'aqui',
#  '⤵',
#  '⤵',
#  '⤵',
#  'síndrome',
#  'estocolmo',
#  '🤣',
#  '🤣',
#  '🤣',
#  'pqp',
#  'kkkkkk',
#  'tá',
#  'difícil',
#  'parar',
#  'coringa',
#  'flamengo',
#  'menino',
#  'jogo',
#  'mengão',
#  'torcida',
#  'show',
#  'pode',
#  'levantar',
#  'plaquinha',
#  'hj',
#  'gol',
#  '🔴',
#  '⚫',
#  '🔴',
#  '⚫',
#  '🔴',
#  '⚫',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  'dá',
#  'chapa',
#  'vola',
#  'kkkkkkkkkkkk',
#  'abraço',
#  'cara',
#  'durma',
#  'bem',
#  'q',
#  'jogar',
#  'lateral',
#  'manter',
#  'marcinho',
#  'meia',
#  'mandar',
#  'fernando',
#  'volta',
#  'pra',
#  'frança',
#  'vão',
#  'trazer',
#  'liberta',
#  'deixa',
#  'gente',
#  'so',
#  'vapo',
#  'vapo',
#  '🙅',
#  '🏻',
#  '\u200d',
#  '♂',
#  '️',
#  'sonho',
#  'ir',
#  'maraca',
#  'amigos',
#  'celebrar',
#  'vendo',
#  'flamengo',
#  'joga',
#  'nunca',
#  'maracanã',
#  'gostaria',
#  'realizar',
#  'sonho',
#  'quero',
#  'nada',
#  'quero',
#  'ver',
#  'flamengo',
#  'joga',
#  'sentir',
#  'emoção',
#  'maraca',
#  'ah',
#  'ta',
#  'kkk',
#  'achei',
#  'tava',
#  'dando',
#  'zicada',
#  'sei',
#  'la',
#  'kkkkkkkkk',
#  'ja',
#  'passeram',
#  'aqui',
#  'poa',
#  'enfim',
#  'elimina',
#  'gremio',
#  'ai',
#  'ta',
#  'tudo',
#  'certo',
#  'kkkkkkkkk',
#  'definição',
#  'pé',
#  'quente',
#  'pra',
#  'vc',
#  'dou',
#  'sorte',
#  'posso',
#  'fazer',
#  'vi',
#  'time',
#  'perder',
#  'trocentos',
#  'jogos',
#  'muitas',
#  'pessoas',
#  'jogos',
#  'viram',
#  'perder',
#  '🙏',
#  'vi',
#  'triste',
#  'desde',
#  'nunca',
#  'vi',
#  'time',
#  'perder',
#  'maraca',
#  'sts',
#  'consegui',
#  'ingresso',
#  'pro',
#  'dia',
#  '23/10',
#  'pé',
#  'quente',
#  'vou',
#  'poder',
#  'ir',
#  'vcs',
#  'podem',
#  'ajudar',
#  'melhor',
#  'dizendo',
#  'adversário',
#  'chego',
#  'gol',
#  'fluminense',
#  'muriel',
#  'tá',
#  'destacando',
#  'odeio',
#  'treinador',
#  'medroso',
#  'medíocre',
#  'ver',
#  'renova',
#  'contrato',
#  'cm',
#  'marcinho',
#  'amadores',
#  'jeito',
#  'q',
#  'vão',
#  'deixar',
#  'sair',
#  'graça',
#  'q',
#  'jogou',
#  'baixo',
#  'liberta',
#  'postando',
#  'merda',
#  'kkkkk',
#  'fluminense',
#  'precisa',
#  'livrar',
#  'kelvin',
#  'ewandro',
#  'agenor',
#  'guilherme',
#  'brenner',
#  'digão',
#  'gilberto',
#  'daniel',
#  'airton',
#  'caio',
#  'pablo',
#  'dyego',
#  'dodi',
#  'pra',
#  'urgente',
#  'menos',
#  'uns',
#  'mil',
#  'pagaria',
#  'jogador',
#  '100x',
#  'melhor',
#  'todos',
#  'juntos',
#  'bom',
#  'dia',
#  '❤',
#  '️',
#  '🖤',
#  'segue',
#  'líder',
#  'timaço',
#  'po',
#  '%',
#  '#',
#  '#wednesdaywisdom',
#  '#flamengo',
#  '#flatv',
#  'acredito',
#  'vitória',
#  'time',
#  'precisa',
#  'mudar',
#  'atitude',
#  'gente',
#  'ainda',
#  'tenta',
#  'ficar',
#  'bola',
#  'estudo',
#  'acho',
#  'q',
#  'q',
#  'mudar',
#  'algumas',
#  'peças',
#  'q',
#  'olhar',
#  'p',
#  'banco',
#  'dê',
#  'medo',
#  'l.fernando',
#  'dose',
#  'ds7',
#  'dá',
#  'tirando',
#  'paciência',
#  'tão',
#  'cavando',
#  'qq',
#  'vaga',
#  'p',
#  'marcinho',
#  'bora',
#  'pra',
#  'praia',
#  'amanhã',
#  'peida',
#  'engraçado',
#  'pq',
#  'agora',
#  'pq',
#  'ano',
#  'ex',
#  'jogadores',
#  'convocados',
#  '#cbflixo',
#  'li',
#  'nenhuma',
#  'nota',
#  'neste',
#  'sentido',
#  'agora',
#  'pq',
#  'cheirinho',
#  'lá',
#  'vc',
#  'solta',
#  'dessa',
#  'nao',
#  'ofende',
#  'cara',
#  'agora',
#  'jogou',
#  'baixo',
#  'kkkkkkkk',
#  'todos',
#  'meses',
#  'consigo',
#  'ir',
#  'ainda',
#  'moro',
#  'rio',
#  'muitooooos',
#  'jogos',
#  'preciso',
#  'mentir',
#  'vi',
#  'flamengo',
#  'perder',
#  '#redacaosportv',
#  'música',
#  'gilberto',
#  'gil',
#  'homenagem',
#  'flamengo',
#  'contrário',
#  'tricolor',
#  'gil',
#  'fez',
#  'provocação',
#  'flamenguistas',
#  'pois',
#  'fluminense',
#  'acabado',
#  'ser',
#  'campeão',
#  'amo',
#  'seleção',
#  '❤',
#  '️',
#  'kkkkkkk',
#  'goleiro',
#  'fluminense',
#  'chama',
#  'muriel',
#  '=',
#  'tudo',
#  'pra',
#  'mim',
#  'var',
#  'quase',
#  'sempre',
#  'funciona',
#  'contra',
#  'fluminense',
#  'rs',
#  'sistema',
#  'foda',
#  '-',
#  'existe',
#  'opinião',
#  'quanto',
#  'tratamento',
#  'rival',
#  'entendeu',
#  'agora',
#  'ex-funcionário',
#  'clube',
#  'agora',
#  'clube',
#  'rival',
#  'desenhar',
#  'agradecimentos',
#  'dados',
#  'agora',
#  'contra',
#  'cruzeiro',
#  'entendi',
#  'resposta',
#  'vc',
#  'virada',
#  'contra',
#  'atlético',
#  'mineiro',
#  'flamengo',
#  'campeão',
#  'brasileiro',
#  'mundial',
#  'lá',
#  'muitos',
#  'outros',
#  'jogos',
#  'vi',
#  'time',
#  'ser',
#  'campeão',
#  'maracanã',
#  'moro',
#  'rio',
#  'tá',
#  'podia',
#  'pedir',
#  'ser',
#  'convocado',
#  'dessa',
#  'vez',
#  'assim',
#  'guerrero',
#  'fez',
#  'amistosos',
#  'apenas',
#  'amistosos',
#  'orienta',
#  'jogadores',
#  'cássio',
#  'escalou',
#  'outra',
#  'explicação',
#  'po',
#  'desde',
#  'nunca',
#  'viu',
#  'perder',
#  'deve',
#  'ir',
#  'vez',
#  'lor',
#  'ano',
#  'entao',
#  'ne',
#  'kkkkkk',
#  'qlquer',
#  'jeito',
#  'boa',
#  'sorte',
#  'pra',
#  'ser',
#  'flamenguista',
#  'nao',
#  'ser',
#  'assim',
#  'quero',
#  'kkk',
#  'q',
#  'bom',
#  'pois',
#  'cara',
#  'leva',
#  'tudo',
#  'p',
#  'emoção',
#  'acaba',
#  'falando',
#  'merda',
#  'kkkkkk.senso',
#  'nunca',
#  'vi',
#  'flamengo',
#  'perder',
#  'vou',
#  'maracanã',
#  '#boladavez',
#  'queria',
#  'saber',
#  'dizer',
#  'sobre',
#  'jogo',
#  'flamengo',
#  'botafogo',
#  'onde',
#  'gabigol',
#  'rafinha',
#  'principalmente',
#  'coejar',
#  'terem',
#  'sidos',
#  'expulsos',
#  'principalmente',
#  'coejar',
#  'lance',
#  'sobre',
#  'marcinho',
#  'onde',
#  'var',
#  'viu',
#  'fez',
#  'nada',
#  'preocupar',
#  'contratar',
#  'atacante',
#  'pra',
#  'fazer',
#  'sombra',
#  'rony',
#  'athletico',
#  'pr',
#  'ótimo',
#  'nome',
#  '🍪',
#  'rapaz',
#  'jogos',
#  'mengão',
#  'estádios',
#  'tbm',
#  'nunca',
#  'vi',
#  'perder',
#  'vitórias',
#  'empates',
#  'alô',
#  'puder',
#  'dar',
#  'rt',
#  'p',
#  'ajudar',
#  'achar',
#  'alguém',
#  'ingresso',
#  'poderá',
#  'ir',
#  "d'alessandro",
#  'falta',
#  'soberba',
#  'oba',
#  'oba',
#  'lado',
#  'agora',
#  'questão',
#  'honra',
#  'eliminar',
#  'aff',
#  'kkkkkk',
#  'coisa',
#  'linda',
#  'apaixonado',
#  'hetero',
#  '❤',
#  '️',
#  '🖤',
#  'pessoas',
#  'preferem',
#  'criticar',
#  'questionar',
#  'ajudar',
#  'brigadão',
#  'força',
#  '👏',
#  '👏',
#  '🖤',
#  '❤',
#  '️',
#  'caralho',
#  'vou',
#  'vestir',
#  'bh',
#  'qualquer',
#  'semelhança',
#  'mera',
#  'coincidência',
#  'amo',
#  'cara',
#  'recebe',
#  'clube',
#  'representa',
#  'barbaridade',
#  '😔',
#  '😔',
#  '😔',
#  'cada',
#  'botafogo',
#  'paulo',
#  'árbitro',
#  'jean',
#  'pierre',
#  'goncalves',
#  'lima',
#  'rs',
#  'árbitro',
#  'vídeo',
#  'andre',
#  'luiz',
#  'freitas',
#  'castro',
#  'go',
#  'pendurados',
#  'c',
#  'amarelos',
#  'marcinho',
#  'fernando',
#  'joel',
#  'carli',
#  'marcelo',
#  'gilson',
#  'gustavo',
#  'alex',
#  'santana',
#  'léo',
#  'valencia',
#  'pimpão',
#  'luiz',
#  'fernando',
#  'olha',
#  'lindo',
#  'nação',
#  'rubro',
#  'negra',
#  '📺',
#  '📺',
#  '📺',
#  'mil',
#  'pessoas',
#  'negócio',
#  'pé',
#  'quente',
#  'pé',
#  'frio',
#  'faz',
#  'menor',
#  'sentido',
#  'zoeira',
#  'boa',
#  'noite',
#  'pronto',
#  'pra',
#  'descansar',
#  'ja',
#  'esquece',
#  'amo',
#  'copa',
#  'brasil',
#  'artilheiros',
#  'pipico',
#  'santa',
#  'cruz',
#  'luciano',
#  'grêmio',
#  'guerrero',
#  'internacional',
#  'daniel',
#  'amorim',
#  'avaí',
#  'gilberto',
#  'bahia',
#  'carlos',
#  'sánchez',
#  'santos',
#  'nando',
#  'guarani',
#  'b',
#  'gols',
#  'marcados',
#  'fluminense',
#  'b',
#  'gols',
#  'marcados',
#  'botafogo-pb',
#  '#finalcopadobrasil',
#  'dá',
#  'olhada',
#  'nisso',
#  'aqui',
#  'rapidin',
#  'toda',
#  'soberba',
#  'castigada',
#  'srn',
#  'sonhei',
#  'fazia',
#  'churrascada',
#  'aqui',
#  'casa',
#  'chave',
#  'portão',
#  'cr',
#  'kkkkkkkkkkkkkkkkkk',
#  'cara',
#  'gremista',
#  'colorado',
#  'pode',
#  'arnaldo',
#  'kkkk',
#  'bom',
#  'vc',
#  'ofendeu',
#  'fala',
#  'porque',
#  'pau',
#  'representa',
#  'akkkkkkkkk',
#  'fim',
#  'jogo',
#  'fluminense',
#  'corinthians',
#  'possivelmente',
#  'pior',
#  'atuação',
#  'vida',
#  'gilberto',
#  'chega',
#  'vestiário',
#  'oswaldo',
#  'oliveira',
#  'sorri',
#  'grita',
#  'gibaaaa',
#  'ganhou',
#  'todas',
#  'pra',
#  'internar',
#  'atestando',
#  'insanidade',
#  'oswaldo',
#  'boa',
#  'nunca',
#  'vi',
#  'vou',
#  'todos',
#  'muitos',
#  'jogos',
#  'flamengo',
#  'perdeu',
#  'tão',
#  'pouco',
#  'entrosados',
#  'gringos',
#  'tudo',
#  'tímido',
#  'alta',
#  'hoje',
#  'impossivel',
#  'vc',
#  'ir',
#  'jogos',
#  'mes',
#  'nunca',
#  'ter',
#  'perdido',
#  'simplesmente',
#  'impossível',
#  'sigo',
#  'desejando',
#  'boa',
#  'sorte',
#  'ate',
#  'pq',
#  'vc',
#  'vitória',
#  'certa',
#  'kkkkkkkk',
#  '👌',
#  'cada',
#  'pensa',
#  'jeito',
#  'sorte',
#  'blz',
#  'pra',
#  'mim',
#  'tá',
#  'dando',
#  'certo',
#  'capinha',
#  'celular',
#  'lá',
#  'leo',
#  'moura',
#  'gostamos',
#  'tô',
#  'entendendo',
#  'vcs',
#  'coloquei',
#  'queria',
#  'ir',
#  'principalmente',
#  'nesse',
#  'jogo',
#  'dia',
#  'vou',
#  'muitos',
#  'jogos',
#  'consegui',
#  'ingressos',
#  'vcs',
#  'vem',
#  'questionando',
#  'quantidade',
#  'jogos',
#  'vou',
#  'achando',
#  'tô',
#  'mentindo',
#  'pq',
#  'anos',
#  'vejo',
#  'necessidade',
#  'mentir',
#  'deus',
#  'conversas',
#  '😰',
#  '😰',
#  'botafogo',
#  'paulo',
#  'árbitro',
#  'jean',
#  'pierre',
#  'goncalves',
#  'lima',
#  'rs',
#  'árbitro',
#  'vídeo',
#  'andre',
#  'luiz',
#  'freitas',
#  'castro',
#  'go',
#  'pendurados',
#  'c',
#  'amarelos',
#  'marcinho',
#  'fernando',
#  'joel',
#  'carli',
#  'marcelo',
#  'gilson',
#  'gustavo',
#  'alex',
#  'santana',
#  'léo',
#  'valencia',
#  'pimpão',
#  'luiz',
#  'fernando',
#  'gente',
#  'oba',
#  'oba',
#  'ainda',
#  'tô',
#  'tentando',
#  'ainda',
#  'mastigar',
#  'flamengo',
#  'mister',
#  'moeu',
#  'cara',
#  '#redacaosportv',
#  'gilberto',
#  'gil',
#  'torcedor',
#  'fluminense',
#  'trecho',
#  'música',
#  'fala',
#  'alô',
#  'torcida',
#  'flamengo',
#  'provocação',
#  'final',
#  'carioca',
#  '😍',
#  '😍',
#  '😍',
#  '🥰',
#  '🔴',
#  '⚫',
#  'tudo',
#  'bem',
#  'vc',
#  'grandes',
#  'momentos',
#  'constatou',
#  'fato',
#  'vc',
#  'frequentadora',
#  'assídua',
#  'flamengo',
#  'ta',
#  'apostando',
#  'contra',
#  'fla',
#  'sério',
#  'parece',
#  'ser',
#  'aqlas',
#  'redes',
#  'proteção',
#  'construção',
#  'sim',
#  'acorda',
#  '😂',
#  'bonito',
#  'atitude',
#  'vc',
#  'crianças',
#  'condições',
#  'faria',
#  'mesma',
#  'coisa',
#  'hahahahhaa',
#  'criador',
#  'queime',
#  'sofá',
#  'caso',
#  'pegue',
#  'mulher',
#  'amante',
#  'nele',
#  'vamos',
#  'vamos',
#  'agora',
#  'nenê',
#  'taaaa',
#  '❤',
#  'acho',
#  'tá',
#  'querendo',
#  'ser',
#  'feliz',
#  'lado',
#  '🥰',
#  '🇮',
#  '🇹',
#  '👀',
#  '*',
#  'entrevista',
#  'dia',
#  '18/09',
#  'definição',
#  'pé',
#  'quente',
#  'superstição',
#  ...]

# %% [markdown]
# ## Removendo Nome de Times

# %%
def removeTeams(tokens):
    teams_list = ['fluminense',
                  'flamengo',
                  'botafogo',
                  'vasco',
                  'são paulo',
                  'palmeiras',
                  'santos',
                  'corinthians',
                  'cruzeiro',
                  'atlético mg',
                  'atlético mineiro',
                  'atletico mg',
                  'atletico mineiro',
                  'internacional',
                  'gremio',
                  'chapecoense',
                  'avai',
                  'csa',
                  'bahia',
                  'goias',
                  'athletico pr',
                  'athletico paranaense',
                  'atletico paranaense',
                  'atlético paranaense'
                  'ceara',
                  'fortaleza'
                 ]
    return [token for token in tokens if token not in teams_list]

# %%
token_no_teams = removeTeams(tokens_no_pontuation)

# %%
len(token_no_teams)
# Out:
# 2497

# %%
token_no_teams
# Out:
# ['podia',
#  'ter',
#  'ficado',
#  'calado',
#  'sabe',
#  'nada',
#  'ajudem',
#  'pé',
#  'quente',
#  'favor',
#  '❤',
#  '️',
#  '🖤',
#  'deus',
#  'kkkkk',
#  'veio',
#  'tomar',
#  'sopa',
#  'garfo',
#  'deu',
#  'nisso',
#  'aí',
#  'goleiro',
#  'muriel',
#  'anos',
#  'participou',
#  'jogos',
#  'tomou',
#  'gol',
#  'três',
#  'notícias',
#  'aqui',
#  '⤵',
#  '⤵',
#  '⤵',
#  'síndrome',
#  'estocolmo',
#  '🤣',
#  '🤣',
#  '🤣',
#  'pqp',
#  'kkkkkk',
#  'tá',
#  'difícil',
#  'parar',
#  'coringa',
#  'menino',
#  'jogo',
#  'mengão',
#  'torcida',
#  'show',
#  'pode',
#  'levantar',
#  'plaquinha',
#  'hj',
#  'gol',
#  '🔴',
#  '⚫',
#  '🔴',
#  '⚫',
#  '🔴',
#  '⚫',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '🙅',
#  '🏽',
#  '\u200d',
#  '♂',
#  '️',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  '👏',
#  '🏾',
#  'dá',
#  'chapa',
#  'vola',
#  'kkkkkkkkkkkk',
#  'abraço',
#  'cara',
#  'durma',
#  'bem',
#  'q',
#  'jogar',
#  'lateral',
#  'manter',
#  'marcinho',
#  'meia',
#  'mandar',
#  'fernando',
#  'volta',
#  'pra',
#  'frança',
#  'vão',
#  'trazer',
#  'liberta',
#  'deixa',
#  'gente',
#  'so',
#  'vapo',
#  'vapo',
#  '🙅',
#  '🏻',
#  '\u200d',
#  '♂',
#  '️',
#  'sonho',
#  'ir',
#  'maraca',
#  'amigos',
#  'celebrar',
#  'vendo',
#  'joga',
#  'nunca',
#  'maracanã',
#  'gostaria',
#  'realizar',
#  'sonho',
#  'quero',
#  'nada',
#  'quero',
#  'ver',
#  'joga',
#  'sentir',
#  'emoção',
#  'maraca',
#  'ah',
#  'ta',
#  'kkk',
#  'achei',
#  'tava',
#  'dando',
#  'zicada',
#  'sei',
#  'la',
#  'kkkkkkkkk',
#  'ja',
#  'passeram',
#  'aqui',
#  'poa',
#  'enfim',
#  'elimina',
#  'ai',
#  'ta',
#  'tudo',
#  'certo',
#  'kkkkkkkkk',
#  'definição',
#  'pé',
#  'quente',
#  'pra',
#  'vc',
#  'dou',
#  'sorte',
#  'posso',
#  'fazer',
#  'vi',
#  'time',
#  'perder',
#  'trocentos',
#  'jogos',
#  'muitas',
#  'pessoas',
#  'jogos',
#  'viram',
#  'perder',
#  '🙏',
#  'vi',
#  'triste',
#  'desde',
#  'nunca',
#  'vi',
#  'time',
#  'perder',
#  'maraca',
#  'sts',
#  'consegui',
#  'ingresso',
#  'pro',
#  'dia',
#  '23/10',
#  'pé',
#  'quente',
#  'vou',
#  'poder',
#  'ir',
#  'vcs',
#  'podem',
#  'ajudar',
#  'melhor',
#  'dizendo',
#  'adversário',
#  'chego',
#  'gol',
#  'muriel',
#  'tá',
#  'destacando',
#  'odeio',
#  'treinador',
#  'medroso',
#  'medíocre',
#  'ver',
#  'renova',
#  'contrato',
#  'cm',
#  'marcinho',
#  'amadores',
#  'jeito',
#  'q',
#  'vão',
#  'deixar',
#  'sair',
#  'graça',
#  'q',
#  'jogou',
#  'baixo',
#  'liberta',
#  'postando',
#  'merda',
#  'kkkkk',
#  'precisa',
#  'livrar',
#  'kelvin',
#  'ewandro',
#  'agenor',
#  'guilherme',
#  'brenner',
#  'digão',
#  'gilberto',
#  'daniel',
#  'airton',
#  'caio',
#  'pablo',
#  'dyego',
#  'dodi',
#  'pra',
#  'urgente',
#  'menos',
#  'uns',
#  'mil',
#  'pagaria',
#  'jogador',
#  '100x',
#  'melhor',
#  'todos',
#  'juntos',
#  'bom',
#  'dia',
#  '❤',
#  '️',
#  '🖤',
#  'segue',
#  'líder',
#  'timaço',
#  'po',
#  '%',
#  '#',
#  '#wednesdaywisdom',
#  '#flamengo',
#  '#flatv',
#  'acredito',
#  'vitória',
#  'time',
#  'precisa',
#  'mudar',
#  'atitude',
#  'gente',
#  'ainda',
#  'tenta',
#  'ficar',
#  'bola',
#  'estudo',
#  'acho',
#  'q',
#  'q',
#  'mudar',
#  'algumas',
#  'peças',
#  'q',
#  'olhar',
#  'p',
#  'banco',
#  'dê',
#  'medo',
#  'l.fernando',
#  'dose',
#  'ds7',
#  'dá',
#  'tirando',
#  'paciência',
#  'tão',
#  'cavando',
#  'qq',
#  'vaga',
#  'p',
#  'marcinho',
#  'bora',
#  'pra',
#  'praia',
#  'amanhã',
#  'peida',
#  'engraçado',
#  'pq',
#  'agora',
#  'pq',
#  'ano',
#  'ex',
#  'jogadores',
#  'convocados',
#  '#cbflixo',
#  'li',
#  'nenhuma',
#  'nota',
#  'neste',
#  'sentido',
#  'agora',
#  'pq',
#  'cheirinho',
#  'lá',
#  'vc',
#  'solta',
#  'dessa',
#  'nao',
#  'ofende',
#  'cara',
#  'agora',
#  'jogou',
#  'baixo',
#  'kkkkkkkk',
#  'todos',
#  'meses',
#  'consigo',
#  'ir',
#  'ainda',
#  'moro',
#  'rio',
#  'muitooooos',
#  'jogos',
#  'preciso',
#  'mentir',
#  'vi',
#  'perder',
#  '#redacaosportv',
#  'música',
#  'gilberto',
#  'gil',
#  'homenagem',
#  'contrário',
#  'tricolor',
#  'gil',
#  'fez',
#  'provocação',
#  'flamenguistas',
#  'pois',
#  'acabado',
#  'ser',
#  'campeão',
#  'amo',
#  'seleção',
#  '❤',
#  '️',
#  'kkkkkkk',
#  'goleiro',
#  'chama',
#  'muriel',
#  '=',
#  'tudo',
#  'pra',
#  'mim',
#  'var',
#  'quase',
#  'sempre',
#  'funciona',
#  'contra',
#  'rs',
#  'sistema',
#  'foda',
#  '-',
#  'existe',
#  'opinião',
#  'quanto',
#  'tratamento',
#  'rival',
#  'entendeu',
#  'agora',
#  'ex-funcionário',
#  'clube',
#  'agora',
#  'clube',
#  'rival',
#  'desenhar',
#  'agradecimentos',
#  'dados',
#  'agora',
#  'contra',
#  'entendi',
#  'resposta',
#  'vc',
#  'virada',
#  'contra',
#  'atlético',
#  'mineiro',
#  'campeão',
#  'brasileiro',
#  'mundial',
#  'lá',
#  'muitos',
#  'outros',
#  'jogos',
#  'vi',
#  'time',
#  'ser',
#  'campeão',
#  'maracanã',
#  'moro',
#  'rio',
#  'tá',
#  'podia',
#  'pedir',
#  'ser',
#  'convocado',
#  'dessa',
#  'vez',
#  'assim',
#  'guerrero',
#  'fez',
#  'amistosos',
#  'apenas',
#  'amistosos',
#  'orienta',
#  'jogadores',
#  'cássio',
#  'escalou',
#  'outra',
#  'explicação',
#  'po',
#  'desde',
#  'nunca',
#  'viu',
#  'perder',
#  'deve',
#  'ir',
#  'vez',
#  'lor',
#  'ano',
#  'entao',
#  'ne',
#  'kkkkkk',
#  'qlquer',
#  'jeito',
#  'boa',
#  'sorte',
#  'pra',
#  'ser',
#  'flamenguista',
#  'nao',
#  'ser',
#  'assim',
#  'quero',
#  'kkk',
#  'q',
#  'bom',
#  'pois',
#  'cara',
#  'leva',
#  'tudo',
#  'p',
#  'emoção',
#  'acaba',
#  'falando',
#  'merda',
#  'kkkkkk.senso',
#  'nunca',
#  'vi',
#  'perder',
#  'vou',
#  'maracanã',
#  '#boladavez',
#  'queria',
#  'saber',
#  'dizer',
#  'sobre',
#  'jogo',
#  'onde',
#  'gabigol',
#  'rafinha',
#  'principalmente',
#  'coejar',
#  'terem',
#  'sidos',
#  'expulsos',
#  'principalmente',
#  'coejar',
#  'lance',
#  'sobre',
#  'marcinho',
#  'onde',
#  'var',
#  'viu',
#  'fez',
#  'nada',
#  'preocupar',
#  'contratar',
#  'atacante',
#  'pra',
#  'fazer',
#  'sombra',
#  'rony',
#  'athletico',
#  'pr',
#  'ótimo',
#  'nome',
#  '🍪',
#  'rapaz',
#  'jogos',
#  'mengão',
#  'estádios',
#  'tbm',
#  'nunca',
#  'vi',
#  'perder',
#  'vitórias',
#  'empates',
#  'alô',
#  'puder',
#  'dar',
#  'rt',
#  'p',
#  'ajudar',
#  'achar',
#  'alguém',
#  'ingresso',
#  'poderá',
#  'ir',
#  "d'alessandro",
#  'falta',
#  'soberba',
#  'oba',
#  'oba',
#  'lado',
#  'agora',
#  'questão',
#  'honra',
#  'eliminar',
#  'aff',
#  'kkkkkk',
#  'coisa',
#  'linda',
#  'apaixonado',
#  'hetero',
#  '❤',
#  '️',
#  '🖤',
#  'pessoas',
#  'preferem',
#  'criticar',
#  'questionar',
#  'ajudar',
#  'brigadão',
#  'força',
#  '👏',
#  '👏',
#  '🖤',
#  '❤',
#  '️',
#  'caralho',
#  'vou',
#  'vestir',
#  'bh',
#  'qualquer',
#  'semelhança',
#  'mera',
#  'coincidência',
#  'amo',
#  'cara',
#  'recebe',
#  'clube',
#  'representa',
#  'barbaridade',
#  '😔',
#  '😔',
#  '😔',
#  'cada',
#  'paulo',
#  'árbitro',
#  'jean',
#  'pierre',
#  'goncalves',
#  'lima',
#  'rs',
#  'árbitro',
#  'vídeo',
#  'andre',
#  'luiz',
#  'freitas',
#  'castro',
#  'go',
#  'pendurados',
#  'c',
#  'amarelos',
#  'marcinho',
#  'fernando',
#  'joel',
#  'carli',
#  'marcelo',
#  'gilson',
#  'gustavo',
#  'alex',
#  'santana',
#  'léo',
#  'valencia',
#  'pimpão',
#  'luiz',
#  'fernando',
#  'olha',
#  'lindo',
#  'nação',
#  'rubro',
#  'negra',
#  '📺',
#  '📺',
#  '📺',
#  'mil',
#  'pessoas',
#  'negócio',
#  'pé',
#  'quente',
#  'pé',
#  'frio',
#  'faz',
#  'menor',
#  'sentido',
#  'zoeira',
#  'boa',
#  'noite',
#  'pronto',
#  'pra',
#  'descansar',
#  'ja',
#  'esquece',
#  'amo',
#  'copa',
#  'brasil',
#  'artilheiros',
#  'pipico',
#  'santa',
#  'cruz',
#  'luciano',
#  'grêmio',
#  'guerrero',
#  'daniel',
#  'amorim',
#  'avaí',
#  'gilberto',
#  'carlos',
#  'sánchez',
#  'nando',
#  'guarani',
#  'b',
#  'gols',
#  'marcados',
#  'b',
#  'gols',
#  'marcados',
#  'botafogo-pb',
#  '#finalcopadobrasil',
#  'dá',
#  'olhada',
#  'nisso',
#  'aqui',
#  'rapidin',
#  'toda',
#  'soberba',
#  'castigada',
#  'srn',
#  'sonhei',
#  'fazia',
#  'churrascada',
#  'aqui',
#  'casa',
#  'chave',
#  'portão',
#  'cr',
#  'kkkkkkkkkkkkkkkkkk',
#  'cara',
#  'gremista',
#  'colorado',
#  'pode',
#  'arnaldo',
#  'kkkk',
#  'bom',
#  'vc',
#  'ofendeu',
#  'fala',
#  'porque',
#  'pau',
#  'representa',
#  'akkkkkkkkk',
#  'fim',
#  'jogo',
#  'possivelmente',
#  'pior',
#  'atuação',
#  'vida',
#  'gilberto',
#  'chega',
#  'vestiário',
#  'oswaldo',
#  'oliveira',
#  'sorri',
#  'grita',
#  'gibaaaa',
#  'ganhou',
#  'todas',
#  'pra',
#  'internar',
#  'atestando',
#  'insanidade',
#  'oswaldo',
#  'boa',
#  'nunca',
#  'vi',
#  'vou',
#  'todos',
#  'muitos',
#  'jogos',
#  'perdeu',
#  'tão',
#  'pouco',
#  'entrosados',
#  'gringos',
#  'tudo',
#  'tímido',
#  'alta',
#  'hoje',
#  'impossivel',
#  'vc',
#  'ir',
#  'jogos',
#  'mes',
#  'nunca',
#  'ter',
#  'perdido',
#  'simplesmente',
#  'impossível',
#  'sigo',
#  'desejando',
#  'boa',
#  'sorte',
#  'ate',
#  'pq',
#  'vc',
#  'vitória',
#  'certa',
#  'kkkkkkkk',
#  '👌',
#  'cada',
#  'pensa',
#  'jeito',
#  'sorte',
#  'blz',
#  'pra',
#  'mim',
#  'tá',
#  'dando',
#  'certo',
#  'capinha',
#  'celular',
#  'lá',
#  'leo',
#  'moura',
#  'gostamos',
#  'tô',
#  'entendendo',
#  'vcs',
#  'coloquei',
#  'queria',
#  'ir',
#  'principalmente',
#  'nesse',
#  'jogo',
#  'dia',
#  'vou',
#  'muitos',
#  'jogos',
#  'consegui',
#  'ingressos',
#  'vcs',
#  'vem',
#  'questionando',
#  'quantidade',
#  'jogos',
#  'vou',
#  'achando',
#  'tô',
#  'mentindo',
#  'pq',
#  'anos',
#  'vejo',
#  'necessidade',
#  'mentir',
#  'deus',
#  'conversas',
#  '😰',
#  '😰',
#  'paulo',
#  'árbitro',
#  'jean',
#  'pierre',
#  'goncalves',
#  'lima',
#  'rs',
#  'árbitro',
#  'vídeo',
#  'andre',
#  'luiz',
#  'freitas',
#  'castro',
#  'go',
#  'pendurados',
#  'c',
#  'amarelos',
#  'marcinho',
#  'fernando',
#  'joel',
#  'carli',
#  'marcelo',
#  'gilson',
#  'gustavo',
#  'alex',
#  'santana',
#  'léo',
#  'valencia',
#  'pimpão',
#  'luiz',
#  'fernando',
#  'gente',
#  'oba',
#  'oba',
#  'ainda',
#  'tô',
#  'tentando',
#  'ainda',
#  'mastigar',
#  'mister',
#  'moeu',
#  'cara',
#  '#redacaosportv',
#  'gilberto',
#  'gil',
#  'torcedor',
#  'trecho',
#  'música',
#  'fala',
#  'alô',
#  'torcida',
#  'provocação',
#  'final',
#  'carioca',
#  '😍',
#  '😍',
#  '😍',
#  '🥰',
#  '🔴',
#  '⚫',
#  'tudo',
#  'bem',
#  'vc',
#  'grandes',
#  'momentos',
#  'constatou',
#  'fato',
#  'vc',
#  'frequentadora',
#  'assídua',
#  'ta',
#  'apostando',
#  'contra',
#  'fla',
#  'sério',
#  'parece',
#  'ser',
#  'aqlas',
#  'redes',
#  'proteção',
#  'construção',
#  'sim',
#  'acorda',
#  '😂',
#  'bonito',
#  'atitude',
#  'vc',
#  'crianças',
#  'condições',
#  'faria',
#  'mesma',
#  'coisa',
#  'hahahahhaa',
#  'criador',
#  'queime',
#  'sofá',
#  'caso',
#  'pegue',
#  'mulher',
#  'amante',
#  'nele',
#  'vamos',
#  'vamos',
#  'agora',
#  'nenê',
#  'taaaa',
#  '❤',
#  'acho',
#  'tá',
#  'querendo',
#  'ser',
#  'feliz',
#  'lado',
#  '🥰',
#  '🇮',
#  '🇹',
#  '👀',
#  '*',
#  'entrevista',
#  'dia',
#  '18/09',
#  'definição',
#  'pé',
#  'quente',
#  'superstição',
#  'sentido',
#  'olha',
#  'apaga',
#  'tudo',
#  'pq',
#  'burro',
#  'nao',
#  'versão',
#  'dezembro',
#  'fazendo',
#  'apologia',
#  'facção',
#  '😪',
#  '😡',
#  'fã',
#  '😭',
#  '😂',
#  'sei',
#  'convocados',
#  'seleção',
#  'prejudicar',
#  'amiga',
#  'tô',
#  'rindo',
#  'kskskskskksksksksks',
#  '-',
#  'cor',
#  'preferida',
#  '-',
#  'marrom',
#  'provocante',
#  'esquece',
#  'quero',
#  'marcinho',
#  'merda',
#  'msm',
#  'então',
#  ...]

# %%
teste = [('teste', 'ldkjwljd'),('teste', 'kdqjlj'),('teste', 'lfkjjkr'), ('te1ste1', 'lfkjjkr')]
regex = re.compile('teste')
list(filter(lambda x: regex.match(x[0]), teste))
# Out:
# [('teste', 'ldkjwljd'), ('teste', 'kdqjlj'), ('teste', 'lfkjjkr')]
